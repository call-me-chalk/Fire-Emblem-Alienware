# %% [markdown]
# Refine the code from the exploratory Fire Emblem Heroes notebook, create a function(s) that will:
# 1. take a list of names
# 2. use those names to complete a url
# 3. scrape the url for a characters specials, weapons, assits, and passives.
# 4. create a dataframe and add a column for each name of the original table (so that the dataframes will join together with other characters) adding a column with the characters name from the list.
# 5. join the data frames together into four complete dataframes, weapons, assits, specials, and passives.

# %%
#getting all the names first
import requests
from bs4 import BeautifulSoup

names_response = requests.get('http://feheroes.gamepedia.com/Hero_List')
names_content = names_response.content
soup = BeautifulSoup(names_content, 'html.parser')
sel_a = soup.select('.wikitable')
each_char = sel_a[0].find_all('tr')


names_list = []
for char in each_char:
    a_list = char.find_all('a')
    for a in a_list:
        if len(a.text) > 0:
            #print(a.text)
            names_list.append(a.text)
#this for loop prints all of the text associated with the links
#in the table. Fortunately, all the names are links, and all of the
#other links don't return anything for the .text property
#So all of the a.text that are greater than 0 are the names.

print(names_list)
# Out:
# ['Abel', 'Alfonse', 'Alm', 'Anna', 'Arthur', 'Azama', 'Azura', 'Barst', 'Bartre', 'Beruka', 'Bruno', 'Caeda', 'Cain', 'Camilla', 'Camilla (Spring Festival)', 'Camus', 'Catria', 'Cecilia', 'Cherche', 'Chrom', 'Chrom (Spring Festival)', 'Clair', 'Clarine', 'Cordelia', 'Corrin (F)', 'Corrin (M)', 'Donnel', 'Draug', 'Effie', 'Eirika', 'Eldigan', 'Elise', 'Eliwood', 'Ephraim', 'Est', 'Fae', 'Faye', 'Felicia', 'Fir', 'Florina', 'Frederick', 'Gaius', 'Gordin', 'Gunter', 'Gwendolyn', 'Hana', 'Hawkeye', 'Hector', 'Henry', 'Hinata', 'Hinoka', 'Ike', 'Jaffar', 'Jagen', 'Jakob', 'Jeorge', 'Julia', 'Kagero', 'Karel', 'Klein', 'Lachesis', 'Laslow', 'Leo', 'Lilina', 'Linde', 'Lissa', "Lon'qu", 'Lucina', 'Lucina (Spring Festival)', 'Lucius', 'Lukas', 'Lyn', 'Maria', 'Marth', 'Matthew', 'Merric', 'Michalis', 'Minerva', 'Mist', 'Narcian', 'Navarre', 'Niles', 'Ninian', 'Nino', 'Nowi', 'Oboro', 'Odin', 'Ogma', 'Olivia', 'Olwen', 'Palla', 'Peri', 'Priscilla', 'Raigh', 'Raven', 'Rebecca', 'Reinhardt', 'Robin (F)', 'Robin (M)', 'Roy', 'Ryoma', 'Saizo', 'Sakura', 'Sanaki', 'Selena', 'Seliph', 'Serra', 'Setsuna', 'Shanna', 'Sharena', 'Sheena', 'Sophia', 'Soren', 'Stahl', 'Subaki', 'Sully', 'Takumi', 'Tharja', 'Tiki (Adult)', 'Tiki (Young)', 'Titania', 'Ursula', 'Veronica', 'Virion', 'Wrys', 'Xander', 'Xander (Spring Festival)', 'Zephiel']

# %%
#change spaces to underscores in names_list so that it works for urls

names_fixed =[]
for name in names_list:
    a = name.replace(' ','_')
    names_fixed.append(a)
print(names_fixed)
# Out:
# ['Abel', 'Alfonse', 'Alm', 'Anna', 'Arthur', 'Azama', 'Azura', 'Barst', 'Bartre', 'Beruka', 'Bruno', 'Caeda', 'Cain', 'Camilla', 'Camilla_(Spring_Festival)', 'Camus', 'Catria', 'Cecilia', 'Cherche', 'Chrom', 'Chrom_(Spring_Festival)', 'Clair', 'Clarine', 'Cordelia', 'Corrin_(F)', 'Corrin_(M)', 'Donnel', 'Draug', 'Effie', 'Eirika', 'Eldigan', 'Elise', 'Eliwood', 'Ephraim', 'Est', 'Fae', 'Faye', 'Felicia', 'Fir', 'Florina', 'Frederick', 'Gaius', 'Gordin', 'Gunter', 'Gwendolyn', 'Hana', 'Hawkeye', 'Hector', 'Henry', 'Hinata', 'Hinoka', 'Ike', 'Jaffar', 'Jagen', 'Jakob', 'Jeorge', 'Julia', 'Kagero', 'Karel', 'Klein', 'Lachesis', 'Laslow', 'Leo', 'Lilina', 'Linde', 'Lissa', "Lon'qu", 'Lucina', 'Lucina_(Spring_Festival)', 'Lucius', 'Lukas', 'Lyn', 'Maria', 'Marth', 'Matthew', 'Merric', 'Michalis', 'Minerva', 'Mist', 'Narcian', 'Navarre', 'Niles', 'Ninian', 'Nino', 'Nowi', 'Oboro', 'Odin', 'Ogma', 'Olivia', 'Olwen', 'Palla', 'Peri', 'Priscilla', 'Raigh', 'Raven', 'Rebecca', 'Reinhardt', 'Robin_(F)', 'Robin_(M)', 'Roy', 'Ryoma', 'Saizo', 'Sakura', 'Sanaki', 'Selena', 'Seliph', 'Serra', 'Setsuna', 'Shanna', 'Sharena', 'Sheena', 'Sophia', 'Soren', 'Stahl', 'Subaki', 'Sully', 'Takumi', 'Tharja', 'Tiki_(Adult)', 'Tiki_(Young)', 'Titania', 'Ursula', 'Veronica', 'Virion', 'Wrys', 'Xander', 'Xander_(Spring_Festival)', 'Zephiel']

# %%
feh_df_list = []
for i, item in enumerate(names_fixed):
    response = requests.get('https://feheroes.wiki/{0}'.format(item))
    content = response.content
    parser = BeautifulSoup(content, 'html.parser')
    skills_table = parser.select('.skills-table')
    #print(i, len(skills_table))
    if i == 9:
        print(item)
        temp_headers = []
        temp_data = []
        for j in skills_table:
            headers = j.find_all('th')
            temp_hlist = []
            for k in headers:
                temp_hlist.append(k.text)
            temp_headers.append(temp_hlist)
            
            data = j.find_all('td')
            temp_dlist = []
            for l in data:
                temp_dlist.append(l.text)
            temp_data.append(temp_dlist)
        print(temp_headers)
        print(temp_data)
        #headers = skills_table[0].find_all('th')
        #data = skills_table[0].find_all('td')
        #for j in range(0, len(headers)):
        #    print(headers[j].text)
        #for j in range(0, len(data)):
        #    print(data[j].text)
# Out:
# Beruka
# [['Name', 'Might', 'Range', 'Effect', 'SP Cost', 'Default', 'Unlock'], ['Name', 'Cooldown', 'Effect', 'SP Cost', 'Default', 'Unlock'], ['Name', 'Effect', 'SP Cost', 'Unlock', 'Type']]
# [['Iron Axe', '6', '1', '-', '50', '-', '-', 'Steel Axe', '8', '1', '-', '100', '3', '-', 'Killer Axe', '7', '1', 'Accelerates Special trigger (cooldown count-1).', '200', '4', '3', 'Killer Axe+', '11', '1', 'Accelerates Special trigger (cooldown count-1).', '300', '5', '5'], ['Night Sky', '4', 'Grants +50% to damage dealt.', '100', '4', '3', 'Glimmer', '3', 'Grants +50% to damage dealt.', '200', '-', '4'], ['Defiant Def 1', "Grants Def+3 at start of turn if unit's HP ≤ 50%.", '40', '-', 'A', 'Defiant Def 2', "Grants Def+5 at start of turn if unit's HP ≤ 50%.", '80', '3', 'Defiant Def 3', "Grants Def+7 at start of turn if unit's HP ≤ 50%.", '160', '4', 'Lunge', 'If unit initiates attack, after combat, unit and targeted foe swap places.', '150', '3', 'B']]

# %%
import math
import pandas as pd

feh_hero_dict = {}
feh_weapons_dict = {}
feh_assits_dict = {}
feh_specials_dict = {}
feh_passives_dict = {}
for i, name in enumerate(names_fixed):
    response = requests.get('https://feheroes.wiki/{0}'.format(name))
    content = response.content
    parser = BeautifulSoup(content, 'html.parser')
    skills_table = parser.select('.skills-table')
    table_heads = []
    table_data = []
    dataframes = []
    
    for j in skills_table:
        headers = j.find_all('th')
        temp_hlist = []
        for k in headers:
            temp_hlist.append(k.text)
            
        data = j.find_all('td')
        temp_dlist = []
        for l in data:
            temp_dlist.append(l.text)
            
        table_heads.append(temp_hlist)
        table_data.append(temp_dlist)
        
    for index, each in enumerate(table_heads):
        if each[1] == 'Effect':
            intended_passive_total = math.ceil(len(table_data[index])/len(table_heads[index]))
            ipt = intended_passive_total
            #print(ipt)
            passive_fixed = table_data[index][:]
            for m in range(0, ipt):
                start = m * len(table_heads[index])
                end = ((m+1) * len(table_heads[index])) - 1
                #print('end: ', end)
                if m < 3:
                    current_type = table_data[index][4]
                elif m < 6 and m > 2:
                    current_type = table_data[index][17]
                elif m < 9 and m > 5:
                    current_type = table_data[index][30]
                #print(current_type)
                if end > len(passive_fixed) - 1:
                    passive_fixed.insert(end, current_type)
                elif passive_fixed[end] != current_type:
                    passive_fixed.insert(end, current_type)
            table_data[index] = passive_fixed
            #print(table_data[index])
            #print(passive_fixed)
    
    for index, item in enumerate(table_heads):
        #print(len(item), len(table_data[index]))
        #print(table_data[index])
        rows = []
        for i in range(0, int(len(table_data[index])/len(item))):
            temp_l = []
            start = i * len(item)
            for j in range(0, len(item)):
                current = start + j
                temp_l.append(table_data[index][current])
            rows.append(temp_l)
        #print(rows)
        df = pd.DataFrame(rows, columns=item)
        dataframes.append(df)
    #print(dataframes)
    feh_hero_dict[name] = dataframes
                
    

        
#print(feh_hero_dict.keys())
#print(feh_hero_dict.values())
#print(feh_hero_dict['Abel'][0])

for key, value in feh_hero_dict.items():
    print(key)
    print(value)
# Out:
# Robin_(M)
# [         Name Might Range                                       Effect  \
# 0     Thunder     4     2                                            -
# 1   Elthunder     6     2                                            -
# 2   Blárraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Blárraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       5      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Glowing Ember        4  Boosts damage dealt by 50% of unit's Def.     100
# 1        Bonfire        3  Boosts damage dealt by 50% of unit's Def.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,             Name                                             Effect SP Cost  \
# 0  Defiant Spd 1  Grants Spd+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Spd 2  Grants Spd+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Spd 3  Grants Spd+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Spur Def 1        Grants adjacent allies Def+2 during combat.      50
# 4     Spur Def 2        Grants adjacent allies Def+3 during combat.     100
# 5     Spur Def 3        Grants adjacent allies Def+4 during combat.     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    C
# 4      3    C
# 5      4    C  ]
# Veronica
# [       Name Might Range                                             Effect  \
# 0  Élivágar    14     2  If unit initiates attack, bonuses on foes with...
#
#   SP Cost Default Unlock
# 0     400       -      -  ]
# Jakob
# [             Name Might Range  \
# 0     Iron Dagger     3     2
# 1    Steel Dagger     5     2
# 2   Silver Dagger     7     2
# 3  Silver Dagger+    10     2
#
#                                               Effect SP Cost Default Unlock
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 2  After combat, inflicts Def/Res-5 on foe throug...     200       4      -
# 3  After combat, inflicts Def/Res-7 on foe throug...     300       5      5  ,                Name Range                                             Effect  \
# 0  Rally Resistance     1  Grants Res+4 to an adjacent ally until the end...
#
#   SP Cost Default Unlock
# 0     150       4      -  ,          Name                                             Effect SP Cost  \
# 0  Defense +1                                      Grants Def+1.      30
# 1  Defense +2                                      Grants Def+2.      60
# 2  Defense +3                                      Grants Def+3.     120
# 3   Renewal 1  At the start of every fourth turn, restores 10...      60
# 4   Renewal 2  At the start of every third turn, restores 10 HP.     120
# 5   Renewal 3  At the start of every second turn, restores 10...     240
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      4    A
# 3      -    B
# 4      4    B
# 5      5    B  ]
# Gaius
# [            Name Might Range  \
# 0    Iron Dagger     3     2
# 1   Steel Dagger     5     2
# 2   Rogue Dagger     4     2
# 3  Rogue Dagger+     7     2
#
#                                               Effect SP Cost Default Unlock
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 2  After combat, inflicts Def/Res-3 on foe throug...     200       4      3
# 3  After combat, inflicts Def/Res-5 on foe throug...     300       -      5  ,           Name Range                                             Effect  \
# 0  Rally Speed     1  Grants Spd+4 to an adjacent ally until the end...
#
#   SP Cost Default Unlock
# 0     150       4      3  ,             Name                                             Effect SP Cost  \
# 0  Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3         Pass 1   Units can pass through foes if its own HP ≥ 75%.      50
# 4         Pass 2   Units can pass through foes if its own HP ≥ 50%.     100
# 5         Pass 3   Units can pass through foes if its own HP ≥ 25%.     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      3    B
# 5      4    B  ]
# Lucina
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Effective against dragons. At the start of eve...     400       5      -  ,        Name Cooldown                                             Effect  \
# 0  New Moon        3     Resolve combat as if foe suffered Def/Res-30%.
# 1      Luna        3     Resolve combat as if foe suffered Def/Res-50%.
# 2    Aether        5  Resolve combat as if foe suffered Def/Res-50%....
#
#   SP Cost Default Unlock
# 0     100       5      -
# 1     200       -      5
# 2     500       -      5  ,             Name                                             Effect SP Cost  \
# 0  Defiant Spd 1  Grants Spd+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Spd 2  Grants Spd+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Spd 3  Grants Spd+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Spur Atk 1        Grants adjacent allies Atk+2 during combat.      50
# 4     Spur Atk 2        Grants adjacent allies Atk+3 during combat.     100
# 5     Spur Atk 3        Grants adjacent allies Atk+4 during combat.     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      -    C
# 4      -    C
# 5      5    C  ]
# Est
# [           Name Might Range                             Effect SP Cost  \
# 0    Iron Lance     6     1                                  -      50
# 1   Steel Lance     8     1                                  -     100
# 2   Heavy Spear     8     1  Effective against armored units.      200
# 3  Heavy Spear+    12     1  Effective against armored units.      300
#
#   Default Unlock
# 0       -      -
# 1       3      -
# 2       4      3
# 3       -      5  ,     Name Range                                    Effect SP Cost Default  \
# 0  Shove     1  Push adjacent ally 1 space farther away.     150       4
#
#   Unlock
# 0      3  ,             Name                                             Effect SP Cost  \
# 0  Defiant Res 1  Grants Res+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Res 2  Grants Res+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Res 3  Grants Res+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Seal Spd 1  After combat, foe suffers Spd-3 through its ne...      40
# 4     Seal Spd 2  After combat, foe suffers Spd-5 through its ne...      80
# 5     Seal Spd 3  After combat, foe suffers Spd-7 through its ne...     160
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    B
# 4      4    B
# 5      5    B  ]
# Xander
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Siegfried    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Enables counterattack regardless of distance i...     400       -      5  ,             Name Cooldown                                             Effect  \
# 0   Rising Light        5  Before combat this unit initiates, foes in an ...
# 1  Blazing Light        5  Before combat this unit initiates, foes in an ...
#
#   SP Cost Default Unlock
# 0     150       4      3
# 1     300       -      4  ,              Name                                             Effect SP Cost  \
# 0  Armored Blow 1  Grants Def+2 during combat if unit initiates t...      50
# 1  Armored Blow 2  Grants Def+4 during combat if unit initiates t...     100
# 2  Armored Blow 3  Grants Def+6 during combat if unit initiates t...     200
# 3      Spur Def 1        Grants adjacent allies Def+2 during combat.      50
# 4      Spur Def 2        Grants adjacent allies Def+3 during combat.     100
# 5      Spur Def 3        Grants adjacent allies Def+4 during combat.     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      -    C
# 4      4    C
# 5      5    C  ]
# Catria
# [            Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       5      5  ,        Name Cooldown                                          Effect SP Cost  \
# 0  New Moon        3  Resolve combat as if foe suffered Def/Res-30%.     100
# 1      Luna        3  Resolve combat as if foe suffered Def/Res-50%.     200
#
#   Default Unlock
# 0       4      -
# 1       -      4  ,              Name                                             Effect SP Cost  \
# 0  Armored Blow 1  Grants Def+2 during combat if unit initiates t...      50
# 1  Armored Blow 2  Grants Def+4 during combat if unit initiates t...     100
# 2  Armored Blow 3  Grants Def+6 during combat if unit initiates t...     200
# 3      Seal Atk 1  After combat, foe suffers Atk-3 through its ne...      40
# 4      Seal Atk 2  After combat, foe suffers Atk-5 through its ne...      80
# 5      Seal Atk 3  After combat, foe suffers Atk-7 through its ne...     160
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      4    A
# 3      -    B
# 4      4    B
# 5      5    B  ]
# Klein
# [         Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2   Brave Bow     4     2  Spd-5. Effective against flying units. Attacks...
# 3  Brave Bow+     7     2  Spd-5. Effective against flying units. Attacks...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Chilling Wind        4  Boosts damage dealt by 50% of unit's Res.     100
# 1        Glacies        4  Boosts damage dealt by 80% of unit's Res.     200
#
#   Default Unlock
# 0       4      -
# 1       -      4  ,               Name                                             Effect SP Cost  \
# 0     Death Blow 1  Grants Atk+2 during combat if unit initiates t...      50
# 1     Death Blow 2  Grants Atk+4 during combat if unit initiates t...     100
# 2     Death Blow 3  Grants Atk+6 during combat if unit initiates t...     200
# 3  Quick Riposte 1  Unit automatically makes a follow-up attack if...      60
# 4  Quick Riposte 2  Unit automatically makes a follow-up attack if...     120
# 5  Quick Riposte 3  Unit automatically makes a follow-up attack if...     240
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      4    A
# 3      -    B
# 4      4    B
# 5      5    B  ]
# Arthur
# [           Name Might Range  \
# 0      Iron Axe     6     1
# 1     Steel Axe     8     1
# 2   Emerald Axe     8     1
# 3  Emerald Axe+    12     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5  ,    Name Range                              Effect SP Cost Default Unlock
# 0  Swap     1  Swap places with an adjacent ally.     150       4      3,              Name                                             Effect SP Cost  \
# 0           HP +3                               Grants +3 to max HP.      40
# 1           HP +4                               Grants +4 to max HP.      80
# 2           HP +5                               Grants +5 to max HP.     160
# 3  Lancebreaker 1  If unit's HP ≥ 90% in combat against a lance u...      50
# 4  Lancebreaker 2  If unit's HP ≥ 70% in combat against a lance u...     100
# 5  Lancebreaker 3  If unit's HP ≥ 50% in combat against a lance u...     200
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    B
# 4      4    B
# 5      5    B  ]
# Jaffar
# [             Name Might Range  \
# 0     Iron Dagger     3     2
# 1    Steel Dagger     5     2
# 2   Silver Dagger     7     2
# 3  Deathly Dagger    11     2
#
#                                               Effect SP Cost Default Unlock
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 2  After combat, inflicts Def/Res-5 on foe throug...     200       -      -
# 3  After combat, inflicts Def/Res-7 on foe throug...     400       5      -  ,         Name Cooldown                        Effect SP Cost Default Unlock
# 0  Night Sky        4  Grants +50% to damage dealt.     100       -      -
# 1    Glimmer        3  Grants +50% to damage dealt.     200       5      -,                Name                                             Effect  \
# 0  Life and Death 1               Grants Atk/Spd+3.Inflicts Def/Res-3.
# 1  Life and Death 2               Grants Atk/Spd+4.Inflicts Def/Res-4.
# 2  Life and Death 3               Grants Atk/Spd+5.Inflicts Def/Res-5.
# 3    Threaten Spd 1  Inflicts Spd-3 on foes within 2 spaces through...
# 4    Threaten Spd 2  Inflicts Spd-4 on foes within 2 spaces through...
# 5    Threaten Spd 3  Inflicts Spd-5 on foes within 2 spaces through...
#
#   SP Cost Unlock Type
# 0      50      -    A
# 1     100      -    A
# 2     200      5    A
# 3      50      -    C
# 4     100      -    C
# 5     200      5    C  ]
# Donnel
# [           Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       1      -
# 1     100       3      2
# 2     200       4      3
# 3     300       -      5  ,              Name Range                                             Effect  \
# 0  Reciprocal Aid     1  Swap HP with adjacent ally (neither unit can g...
#
#   SP Cost Default Unlock
# 0     150       4      3  ,         Name                                             Effect SP Cost  \
# 0      HP +3                               Grants +3 to max HP.      40
# 1      HP +4                               Grants +4 to max HP.      80
# 2      HP +5                               Grants +5 to max HP.     160
# 3  Drag Back  If unit initiates attack, the unit moves 1 spa...     150
#
#   Unlock Type
# 0      1    A
# 1      2    A
# 2      4    A
# 3      3    B  ]
# Ephraim
# [          Name Might Range                                             Effect  \
# 0   Iron Lance     6     1                                                  -
# 1  Steel Lance     8     1                                                  -
# 2  Heavy Spear     8     1                  Effective against armored units.
# 3     Siegmund    16     1  Grants adjacent allies Atk+3 through their nex...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     400       5      -  ,        Name Cooldown                                          Effect SP Cost  \
# 0  New Moon        3  Resolve combat as if foe suffered Def/Res-30%.     100
# 1   Moonbow        2  Resolve combat as if foe suffered Def/Res-30%.     200
#
#   Default Unlock
# 0       5      -
# 1       -      5  ,              Name                                             Effect SP Cost  \
# 0      Seal Def 1  After combat, foe suffers Def-3 through its ne...      40
# 1      Seal Def 2  After combat, foe suffers Def-5 through its ne...      80
# 2      Seal Def 3  After combat, foe suffers Def-7 through its ne...     160
# 3  Threaten Def 1  Inflicts Def-3 on foes within 2 spaces through...      50
# 4  Threaten Def 2  Inflicts Def-4 on foes within 2 spaces through...     100
# 5  Threaten Def 3  Inflicts Def-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      -    B
# 1      -    B
# 2      5    B
# 3      -    C
# 4      -    C
# 5      5    C  ]
# Lon'qu
# [            Name Might Range                                           Effect  \
# 0     Iron Sword     6     1                                                -
# 1    Steel Sword     8     1                                                -
# 2   Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killing Edge+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,         Name Cooldown                        Effect SP Cost Default Unlock
# 0  Night Sky        4  Grants +50% to damage dealt.     100       4      3
# 1    Glimmer        3  Grants +50% to damage dealt.     200       -      4,         Name                                             Effect SP Cost  \
# 0   Speed +1                                      Grants Spd+1.      30
# 1   Speed +2                                      Grants Spd+2.      60
# 2   Speed +3                                      Grants Spd+3.     120
# 3  Vantage 1  Unit counterattacks first when attacked at HP ...      50
# 4  Vantage 2  Unit counterattacks first when attacked at HP ...     100
# 5  Vantage 3  Unit counterattacks first when attacked at HP ...     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      3    B
# 5      4    B  ]
# Camilla_(Spring_Festival)
# [         Name Might Range                                             Effect  \
# 0        Wind     4     2                                                  -
# 1      Elwind     6     2                                                  -
# 2   Green Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 3  Green Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     300       5      -  ,            Name Range                                             Effect  \
# 0  Rally Attack     1  Grants Atk+4 to an adjacent ally until the end...
#
#   SP Cost Default Unlock
# 0     150       5      -  ,               Name                                             Effect SP Cost  \
# 0    Defiant Spd 1  Grants Spd+3 at start of turn if unit's HP ≤ 50%.      40
# 1    Defiant Spd 2  Grants Spd+5 at start of turn if unit's HP ≤ 50%.      80
# 2    Defiant Spd 3  Grants Spd+7 at start of turn if unit's HP ≤ 50%.     160
# 3  Live for Bounty  If unit survives, get 1.5x shards/crystals fro...     100
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      5    B  ]
# Barst
# [         Name Might Range                                       Effect  \
# 0    Iron Axe     6     1                                            -
# 1   Steel Axe     8     1                                            -
# 2   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,          Name Range                                         Effect SP Cost  \
# 0  Reposition     1  Moves adjacent ally to opposite side of unit.     150
#
#   Default Unlock
# 0       4      3  ,          Name                                             Effect  \
# 0  Knock Back  If unit initiates attack, foe is moved 1 space...
# 1  Spur Atk 1        Grants adjacent allies Atk+2 during combat.
# 2           C                                         Spur Atk 2
# 3           3                                         Spur Atk 3
#
#                                        SP Cost Unlock Type
# 0                                          150      3    B
# 1                                           50      -    B
# 2  Grants adjacent allies Atk+3 during combat.    100    B
# 3  Grants adjacent allies Atk+4 during combat.    200    4  ]
# Seliph
# [           Name Might Range                                      Effect  \
# 0    Iron Sword     6     1                                           -
# 1   Steel Sword     8     1                                           -
# 2  Silver Sword    11     1                                           -
# 3       Tyrfing    16     1  Grants Def+4 in battle if unit's HP ≤ 50%.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     400       5      5  ,           Name Range                                             Effect  \
# 0  Rally Speed     1  Grants Spd+4 to an adjacent ally until the end...
#
#   SP Cost Default Unlock
# 0     150       4      -  ,               Name                                             Effect SP Cost  \
# 0            HP +3                               Grants +3 to max HP.      40
# 1            HP +4                               Grants +4 to max HP.      80
# 2            HP +5                               Grants +5 to max HP.     160
# 3  Brash Assault 1  Unit automatically makes a follow-up when at H...      50
# 4  Brash Assault 2  Unit automatically makes a follow-up when at H...     100
# 5  Brash Assault 3  Unit automatically makes a follow-up when at H...     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      4    A
# 3      -    B
# 4      4    B
# 5      5    B  ]
# Fae
# [            Name Might Range  \
# 0    Fire Breath     6     1
# 1   Fire Breath+     8     1
# 2   Light Breath     9     1
# 3  Light Breath+    13     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2  Grants adjacent allies Def/Res+4 through their...     200       4      -
# 3  Grants adjacent allies Def/Res+4 through their...     300       5      5  ,         Name Range                                             Effect SP Cost  \
# 0  Draw Back     1  Unit moves 1 space away from target ally, who ...     150
#
#   Default Unlock
# 0       4      -  ,              Name                                             Effect SP Cost  \
# 0       Renewal 1  At the start of every fourth turn, restores 10...      60
# 1       Renewal 2  At the start of every third turn, restores 10 HP.     120
# 2       Renewal 3  At the start of every second turn, restores 10...     240
# 3  Threaten Atk 1  Inflicts Atk-3 on foes within 2 spaces through...      50
# 4  Threaten Atk 2  Inflicts Atk-4 on foes within 2 spaces through...     100
# 5  Threaten Atk 3  Inflicts Atk-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      -    B
# 1      -    B
# 2      4    B
# 3      -    C
# 4      4    C
# 5      5    C  ]
# Setsuna
# [              Name Might Range  \
# 0         Iron Bow     4     2
# 1        Steel Bow     6     2
# 2   Assassin's Bow     7     2
# 3  Assassin's Bow+    11     2
#
#                                               Effect SP Cost Default Unlock
# 0                   Effective against flying units.       50       -      -
# 1                   Effective against flying units.      100       3      -
# 2  Effective against flying units. If target has ...     200       4      3
# 3  Effective against flying units. If target has ...     300       5      5  ,              Name Range                                             Effect  \
# 0  Reciprocal Aid     1  Swap HP with adjacent ally (neither unit can g...
#
#   SP Cost Default Unlock
# 0     150       4      3  ,            Name                                             Effect SP Cost  \
# 0         HP +3                               Grants +3 to max HP.      40
# 1         HP +4                               Grants +4 to max HP.      80
# 2         HP +5                               Grants +5 to max HP.     160
# 3  Bowbreaker 1  If unit's HP ≥ 90% in combat against a bow use...      50
# 4  Bowbreaker 2  If unit's HP ≥ 70% in combat against a bow use...     100
# 5  Bowbreaker 3  If unit's HP ≥ 50% in combat against a bow use...     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      3    B
# 5      4    B  ]
# Robin_(F)
# [         Name Might Range                            Effect SP Cost Default  \
# 0        Wind     4     2                                 -      50       2
# 1      Elwind     6     2                                 -     100       3
# 2   Gronnwolf     6     2  Effective against cavalry units.     200       4
# 3  Gronnwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock
# 0      -
# 1      2
# 2      3
# 3      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Glowing Ember        4  Boosts damage dealt by 50% of unit's Def.     100
# 1          Ignis        4  Boosts damage dealt by 80% of unit's Def.     200
#
#   Default Unlock
# 0       -      3
# 1       -      4  ,               Name                                             Effect SP Cost  \
# 0    Defiant Res 1  Grants Res+3 at start of turn if unit's HP ≤ 50%.      40
# 1    Defiant Res 2  Grants Res+5 at start of turn if unit's HP ≤ 50%.      80
# 2    Defiant Res 3  Grants Res+7 at start of turn if unit's HP ≤ 50%.     160
# 3  B Tomebreaker 1  If unit's HP ≥ 90% in combat against a blue to...      50
# 4  B Tomebreaker 2  If unit's HP ≥ 70% in combat against a blue to...     100
# 5  B Tomebreaker 3  If unit's HP ≥ 50% in combat against a blue to...     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      2    B
# 4      3    B
# 5      4    B  ]
# Nino
# [          Name Might Range                                             Effect  \
# 0         Wind     4     2                                                  -
# 1       Elwind     6     2                                                  -
# 2   Gronnblade     9     2  Slows Special trigger (cooldown count+1).Adds ...
# 3  Gronnblade+    13     2  Slows Special trigger (cooldown count+1).Adds ...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,         Name Range                                             Effect SP Cost  \
# 0  Draw Back     1  Unit moves 1 space away from target ally, who ...     150
#
#   Default Unlock
# 0       4      3  ,             Name                                             Effect SP Cost  \
# 0  Resistance +1                                      Grants Res+1.      30
# 1  Resistance +2                                      Grants Res+2.      60
# 2  Resistance +3                                      Grants Res+3.     120
# 3     Hone Atk 1  Grants adjacent allies Atk+2 through their nex...      50
# 4     Hone Atk 2  Grants adjacent allies Atk+3 through their nex...     100
# 5     Hone Atk 3  Grants adjacent allies Atk+4 through their nex...     200
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Niles
# [          Name Might Range                                             Effect  \
# 0     Iron Bow     4     2                   Effective against flying units.
# 1    Steel Bow     6     2                   Effective against flying units.
# 2   Killer Bow     5     2  Effective against flying units. Accelerates Sp...
# 3  Killer Bow+     9     2  Effective against flying units. Accelerates Sp...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Chilling Wind        4  Boosts damage dealt by 50% of unit's Res.     100
# 1        Iceberg        3  Boosts damage dealt by 50% of unit's Res.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,              Name                                             Effect SP Cost  \
# 0  Warding Blow 1  Grants Res+2 during combat if unit initiates a...      50
# 1  Warding Blow 2  Grants Res+4 during combat if unit initiates a...     100
# 2  Warding Blow 3  Grants Res+6 during combat if unit initiates a...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5      Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Navarre
# [            Name Might Range                                           Effect  \
# 0     Iron Sword     6     1                                                -
# 1    Steel Sword     8     1                                                -
# 2   Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killing Edge+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,            Name Cooldown                                             Effect  \
# 0   Rising Wind        5  Before combat this unit initiates, foes in an ...
# 1  Blazing Wind        5  Before combat this unit initiates, foes in an ...
#
#   SP Cost Default Unlock
# 0     150       4      3
# 1     300       -      4  ,              Name                                             Effect SP Cost  \
# 0   Desperation 1  If unit initiates combat with HP ≤ 25%, follow...      50
# 1   Desperation 2  If unit initiates combat with HP ≤ 50%, follow...     100
# 2   Desperation 3  If unit initiates combat with HP ≤ 75%, follow...     200
# 3  Threaten Spd 1  Inflicts Spd-3 on foes within 2 spaces through...      50
# 4  Threaten Spd 2  Inflicts Spd-4 on foes within 2 spaces through...     100
# 5  Threaten Spd 3  Inflicts Spd-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      3    B
# 1      4    B
# 2      5    B
# 3      -    C
# 4      3    C
# 5      4    C  ]
# Alfonse
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Fólkvangr    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       2      -
# 1                                                  -     100       -      2
# 2                                                  -     200       -      3
# 3  Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5  ,        Name Cooldown                     Effect SP Cost Default Unlock
# 0  Daylight        4  Heal 30% of damage dealt.     100       2      -
# 1       Sol        4  Heal 50% of damage dealt.     200       -      4,            Name                                             Effect SP Cost  \
# 0  Death Blow 1  Grants Atk+2 during combat if unit initiates t...      50
# 1  Death Blow 2  Grants Atk+4 during combat if unit initiates t...     100
# 2  Death Blow 3  Grants Atk+6 during combat if unit initiates t...     200
# 3    Spur Atk 1        Grants adjacent allies Atk+2 during combat.      50
# 4    Spur Atk 2        Grants adjacent allies Atk+3 during combat.     100
# 5    Spur Atk 3        Grants adjacent allies Atk+4 during combat.     200
#
#   Unlock Type
# 0      1    A
# 1      2    A
# 2      4    A
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Draug
# [           Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       2      -
# 1     100       -      2
# 2     200       4      3
# 3     300       5      5  ,       Name Cooldown                                             Effect  \
# 0  Buckler        3  Reduces damage inflicted by attacks from adjac...
# 1   Pavise        3  Reduces damage inflicted by attacks from adjac...
#
#   SP Cost Default Unlock
# 0     100       4      3
# 1     200       -      4  ,          Name                                             Effect  \
# 0       Lunge  If unit initiates attack, after combat, unit a...
# 1  Spur Def 1        Grants adjacent allies Def+2 during combat.
# 2           C                                         Spur Def 2
# 3           2                                         Ward Armor
#
#                                              SP Cost Unlock Type
# 0                                                150      3    B
# 1                                                 50      -    B
# 2        Grants adjacent allies Def+3 during combat.    100    B
# 3  Grants armored allies within 2 spaces Def/Res+...    200    4  ]
# Eliwood
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Durandal    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Grants Atk+4 during combat if unit initiates a...     400       5      5  ,              Name Cooldown                                             Effect  \
# 0  Holy Vestments        3  Reduces damage inflicted by attacks from foes ...
# 1     Sacred Cowl        2  Reduces damage inflicted by attacks from foes ...
#
#   SP Cost Default Unlock
# 0     100       4      3
# 1     200       -      4  ,            Name                                             Effect SP Cost  \
# 0  Axebreaker 1  If unit's HP ≥ 90% in combat against an axe us...      50
# 1  Axebreaker 2  If unit's HP ≥ 70% in combat against an axe us...     100
# 2  Axebreaker 3  If unit's HP ≥ 50% in combat against an axe us...     200
# 3    Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4    Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5  Ward Cavalry  Grants cavalry allies within 2 spaces Def/Res+...     200
#
#   Unlock Type
# 0      3    B
# 1      4    B
# 2      5    B
# 3      -    C
# 4      3    C
# 5      4    C  ]
# Faye
# [             Name Might Range  \
# 0        Iron Bow     4     2
# 1       Steel Bow     6     2
# 2   Firesweep Bow     7     2
# 3  Firesweep Bow+    11     2
#
#                                               Effect SP Cost Default Unlock
# 0                   Effective against flying units.       50       -      -
# 1                   Effective against flying units.      100       -      -
# 2  Effective against flying units. Unit and enemi...     200       -      -
# 3  Effective against flying units. Unit and enemi...     300       5      -  ,        Name Cooldown                     Effect SP Cost Default Unlock
# 0  Daylight        4  Heal 30% of damage dealt.     100       5      -
# 1  Noontime        3  Heal 30% of damage dealt.     200       -      5,                Name                                             Effect  \
# 0  Wings of Mercy 1  Enables unit to warp adjacent to any ally with...
# 1  Wings of Mercy 2  Enables unit to warp adjacent to any ally with...
# 2  Wings of Mercy 3  Enables unit to warp adjacent to any ally with...
# 3        Bow Exp. 1  If unit survives and uses a bow, unit gets 1.5...
# 4        Bow Exp. 2  If unit survives, all bow users on team get 1....
# 5        Bow Exp. 3  If unit survives, all bow users on team get 2x...
#
#   SP Cost Unlock Type
# 0      60      -    B
# 1     120      -    B
# 2     240      5    B
# 3      50      -    C
# 4     100      -    C
# 5     200      5    C  ]
# Zephiel
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Eckesachs    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Inflicts Def-4 on foes within 2 spaces through...     400       -      5  ,           Name Cooldown                                             Effect  \
# 0  Retribution        3  Grants bonus to damage dealt equal to 30% of d...
# 1     Reprisal        2  Grants bonus to damage dealt equal to 30% of d...
#
#   SP Cost Default Unlock
# 0     100       4      3
# 1     200       -      4  ,                Name                                             Effect  \
# 0  Life and Death 1               Grants Atk/Spd+3.Inflicts Def/Res-3.
# 1  Life and Death 2               Grants Atk/Spd+4.Inflicts Def/Res-4.
# 2  Life and Death 3               Grants Atk/Spd+5.Inflicts Def/Res-5.
# 3    Wary Fighter 1  Prevents follow-up attacks in combat from unit...
# 4    Wary Fighter 2  Prevents follow-up attacks in combat from unit...
# 5    Wary Fighter 3  Prevents follow-up attacks in combat from unit...
#
#   SP Cost Unlock Type
# 0      50      -    A
# 1     100      4    A
# 2     200      5    A
# 3      60      -    B
# 4     120      -    B
# 5     240      4    B  ]
# Lachesis
# [      Name Might Range                            Effect SP Cost Default  \
# 0  Assault    10     2                                 -      50       -
# 1   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#   Unlock
# 0      -
# 1      4  ,      Name Range                  Effect SP Cost Default Unlock
# 0    Heal     1          Restores 5 HP.       -       -      -
# 1    Mend     1         Restores 10 HP.     100       4      -
# 2  Physic     2  Restores 8 HP. Rng: 2.     200       5      4,                Name Cooldown  \
# 0             Imbue        1
# 1  Solid-Earth Balm        1
#
#                                               Effect SP Cost Default Unlock
# 0  When healing an ally with a staff, increases r...      50       4      -
# 1  When healing an ally with a staff, grants all ...     150       5      4  ,          Name                                       Effect SP Cost Unlock Type
# 0  Spur Res 1  Grants adjacent allies Res+2 during combat.      50      -    C
# 1  Spur Res 2  Grants adjacent allies Res+3 during combat.     100      4    C
# 2  Spur Res 3  Grants adjacent allies Res+4 during combat.     200      5    C]
# Sharena
# [           Name Might Range  \
# 0    Iron Lance     6     1
# 1   Steel Lance     8     1
# 2  Silver Lance    11     1
# 3      Fensalir    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       2      -
# 1                                                  -     100       -      2
# 2                                                  -     200       -      3
# 3  Inflicts Atk-4 on foes within 2 spaces through...     400       -      5  ,            Name Range                                             Effect  \
# 0  Rally Attack     1  Grants Atk+4 to an adjacent ally until the end...
#
#   SP Cost Default Unlock
# 0     150       2      -  ,             Name                                             Effect SP Cost  \
# 0       Speed +1                                      Grants Spd+1.      30
# 1       Speed +2                                      Grants Spd+2.      60
# 2       Speed +3                                      Grants Spd+3.     120
# 3  Fortify Def 1  Grants adjacent allies Def+2 through their nex...      50
# 4  Fortify Def 2  Grants adjacent allies Def+3 through their nex...     100
# 5  Fortify Def 3  Grants adjacent allies Def+4 through their nex...     200
#
#   Unlock Type
# 0      1    A
# 1      2    A
# 2      4    A
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Minerva
# [         Name Might Range                                           Effect  \
# 0    Iron Axe     6     1                                                -
# 1   Steel Axe     8     1                                                -
# 2  Silver Axe    11     1                                                -
# 3  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     400       5      -  ,              Name Cooldown                                             Effect  \
# 0  Holy Vestments        3  Reduces damage inflicted by attacks from foes ...
# 1     Sacred Cowl        2  Reduces damage inflicted by attacks from foes ...
#
#   SP Cost Default Unlock
# 0     100       5      -
# 1     200       -      5  ,                Name                                             Effect  \
# 0  Life and Death 1               Grants Atk/Spd+3.Inflicts Def/Res-3.
# 1  Life and Death 2               Grants Atk/Spd+4.Inflicts Def/Res-4.
# 2  Life and Death 3               Grants Atk/Spd+5.Inflicts Def/Res-5.
# 3        Spur Def 1        Grants adjacent allies Def+2 during combat.
# 4        Spur Def 2        Grants adjacent allies Def+3 during combat.
# 5       Ward Fliers  Grants flying allies within 2 spaces Def/Res+4...
#
#   SP Cost Unlock Type
# 0      50      -    A
# 1     100      -    A
# 2     200      5    A
# 3      50      -    C
# 4     100      -    C
# 5     200      5    C  ]
# Mist
# [      Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     150       -      5  ,       Name Range                                             Effect SP Cost  \
# 0     Heal     1                                     Restores 5 HP.       -
# 1     Mend     1                                    Restores 10 HP.     100
# 2  Recover     1  Restores 15 HP.Slows Special trigger (cooldown...     200
#
#   Default Unlock
# 0       -      -
# 1       -      -
# 2       5      -  ,       Name Cooldown                                             Effect  \
# 0    Imbue        1  When healing an ally with a staff, increases r...
# 1  Miracle        5  If HP > 1, survive a lethal attack with 1 HP r...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     200       5      -  ,              Name                                            Effect SP Cost  \
# 0      Spur Res 1       Grants adjacent allies Res+2 during combat.      50
# 1  Spur Def Res 1   Grants adjacent allies Def/Res +2 during combat     120
# 2  Spur Def Res 2  Grants adjacent allies Def/Res +3 during combat.     240
#
#   Unlock Type
# 0      -    C
# 1      -    C
# 2      5    C  ]
# Shanna
# [            Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Chilling Wind        4  Boosts damage dealt by 50% of unit's Res.     100
# 1        Iceberg        3  Boosts damage dealt by 50% of unit's Res.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,              Name                                             Effect SP Cost  \
# 0   Desperation 1  If unit initiates combat with HP ≤ 25%, follow...      50
# 1   Desperation 2  If unit initiates combat with HP ≤ 50%, follow...     100
# 2   Desperation 3  If unit initiates combat with HP ≤ 75%, follow...     200
# 3  Threaten Spd 1  Inflicts Spd-3 on foes within 2 spaces through...      50
# 4  Threaten Spd 2  Inflicts Spd-4 on foes within 2 spaces through...     100
# 5  Threaten Spd 3  Inflicts Spd-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      -    B
# 1      3    B
# 2      4    B
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Elise
# [      Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     150       -      -  ,       Name Range                                             Effect SP Cost  \
# 0     Heal     1                                     Restores 5 HP.       -
# 1     Mend     1                                    Restores 10 HP.     100
# 2  Recover     1  Restores 15 HP.Slows Special trigger (cooldown...     200
#
#   Default Unlock
# 0       -      -
# 1       -      -
# 2       5      -  ,                 Name Cooldown  \
# 0              Imbue        1
# 1  Kindled-Fire Balm        1
#
#                                               Effect SP Cost Default Unlock
# 0  When healing an ally with a staff, increases r...      50       -      -
# 1  When healing an ally with a staff, grants all ...     150       5      -  ,               Name                                             Effect SP Cost  \
# 0  Live to Serve 1  When healing allies with a staff, unit also re...      40
# 1  Live to Serve 2  When healing allies with a staff, unit also re...      80
# 2  Live to Serve 3  When healing allies with a staff, unit also re...     160
#
#   Unlock Type
# 0      -    B
# 1      -    B
# 2      5    B  ]
# Clair
# ...
#
#   Unlock Type
# 0      -    B
# 1      -    B
# 2      4    B
# 3      -    C
# 4      4    C
# 5      5    C  ]
# Chrom_(Spring_Festival)
# [          Name Might Range                                             Effect  \
# 0     Iron Axe     6     1                                                  -
# 1    Steel Axe     8     1                                                  -
# 2   Carrot Axe     9     1  If unit initiates attack, unit recovers 4 HP a...
# 3  Carrot Axe+    13     1  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     300       5      -  ,     Name Range                                    Effect SP Cost Default  \
# 0  Shove     1  Push adjacent ally 1 space farther away.     150       5
#
#   Unlock
# 0      -  ,                Name                                             Effect  \
# 0        Defense +1                                      Grants Def+1.
# 1     Attack Def +1                                  Grants Atk/Def+1.
# 2     Attack Def +2                                  Grants Atk/Def+2.
# 3  Axe Experience 1  If unit survives, unit gets 1.5x EXP.(If simil...
# 4  Axe Experience 2  If unit survives, all axe users on team get 1....
# 5  Axe Experience 3  If unit survives, all axe users on team get 2x...
#
#   SP Cost Unlock Type
# 0      30      -    A
# 1      80      -    A
# 2     160      5    A
# 3      50      -    C
# 4     100      -    C
# 5     200      5    C  ]
# Odin
# [         Name Might Range                                             Effect  \
# 0     Thunder     4     2                                                  -
# 1   Elthunder     6     2                                                  -
# 2   Blárblade     9     2  Slows Special trigger (cooldown count+1).Adds ...
# 3  Blárblade+    13     2  Slows Special trigger (cooldown count+1).Adds ...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,        Name Cooldown                                          Effect SP Cost  \
# 0  New Moon        3  Resolve combat as if foe suffered Def/Res-30%.     100
# 1   Moonbow        2  Resolve combat as if foe suffered Def/Res-30%.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,               Name                                             Effect SP Cost  \
# 0    Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1    Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2    Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3  R Tomebreaker 1  If unit's HP ≥ 90% in combat against a red tom...      50
# 4  R Tomebreaker 2  If unit's HP ≥ 70% in combat against a red tom...     100
# 5  R Tomebreaker 3  If unit's HP ≥ 50% in combat against a red tom...     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      3    B
# 5      4    B  ]
# Lucius
# [      Name Might Range                                            Effect  \
# 0  Assault    10     2                                                 -
# 1     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#   SP Cost Default Unlock
# 0      50       -      4
# 1     150       -      4  ,         Name Range                                             Effect SP Cost  \
# 0       Heal     1                                     Restores 5 HP.       -
# 1  Reconcile     1        Restores 7 HP each to target and this unit.     100
# 2     Martyr     1  Restores HP=7+ this unit's suffered damage.Uni...     200
#
#   Default Unlock
# 0       -      -
# 1       4      -
# 2       5      4  ,       Name Cooldown                                             Effect  \
# 0    Imbue        1  When healing an ally with a staff, increases r...
# 1  Miracle        5  If HP > 1, survive a lethal attack with 1 HP r...
#
#   SP Cost Default Unlock
# 0      50       4      -
# 1     200       5      4  ,     Name                Effect SP Cost Unlock Type
# 0  HP +3  Grants +3 to max HP.      40      -    A
# 1  HP +4  Grants +4 to max HP.      80      4    A
# 2  HP +5  Grants +5 to max HP.     160      5    A]
# Cordelia
# [           Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,         Name Cooldown                                             Effect  \
# 0  Night Sky        4                       Grants +50% to damage dealt.
# 1      Astra        5                      Grants +150% to damage dealt.
# 2  Galeforce        5  If this unit initiates an attack, it can take ...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4
# 2     500       -      5  ,                Name                                             Effect  \
# 0  Triangle Adept 1  Gives Atk+10% if weapon-triangle advantage, At...
# 1  Triangle Adept 2  Gives Atk+15% if weapon-triangle advantage, At...
# 2  Triangle Adept 3  Gives Atk+20% if weapon-triangle advantage, At...
# 3            Pass 1   Units can pass through foes if its own HP ≥ 75%.
# 4            Pass 2   Units can pass through foes if its own HP ≥ 50%.
# 5            Pass 3   Units can pass through foes if its own HP ≥ 25%.
#
#   SP Cost Unlock Type
# 0      50      -    A
# 1     100      4    A
# 2     200      5    A
# 3      50      -    B
# 4     100      -    B
# 5     200      4    B  ]
# Ogma
# [           Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,        Name Cooldown                     Effect SP Cost Default Unlock
# 0  Daylight        4  Heal 30% of damage dealt.     100       4      -
# 1  Noontime        3  Heal 30% of damage dealt.     200       -      4,             Name                                             Effect SP Cost  \
# 0  Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Spur Atk 1        Grants adjacent allies Atk+2 during combat.      50
# 4     Spur Atk 2        Grants adjacent allies Atk+3 during combat.     100
# 5     Spur Atk 3        Grants adjacent allies Atk+4 during combat.     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      4    A
# 3      -    C
# 4      4    C
# 5      5    C  ]
# Hana
# [           Name Might Range                             Effect SP Cost  \
# 0    Iron Sword     6     1                                  -      50
# 1   Steel Sword     8     1                                  -     100
# 2   Armorslayer     8     1  Effective against armored units.      200
# 3  Armorslayer+    12     1  Effective against armored units.      300
#
#   Default Unlock
# 0       1      -
# 1       3      2
# 2       4      3
# 3       5      5  ,            Name Range                                             Effect  \
# 0  Rally Attack     1  Grants Atk+4 to an adjacent ally until the end...
#
#   SP Cost Default Unlock
# 0     150       4      3  ,                Name                                             Effect  \
# 0  Life and Death 1               Grants Atk/Spd+3.Inflicts Def/Res-3.
# 1  Life and Death 2               Grants Atk/Spd+4.Inflicts Def/Res-4.
# 2  Life and Death 3               Grants Atk/Spd+5.Inflicts Def/Res-5.
# 3        Obstruct 1  Prevents foes from moving through adjacent spa...
# 4        Obstruct 2  Prevents foes from moving through adjacent spa...
# 5        Obstruct 3  Prevents foes from moving through adjacent spa...
#
#   SP Cost Unlock Type
# 0      50      3    A
# 1     100      4    A
# 2     200      5    A
# 3      50      1    B
# 4     100      2    B
# 5     200      4    B  ]
# Tharja
# [          Name Might Range                                             Effect  \
# 0         Flux     4     2                                                  -
# 1         Ruin     6     2                                                  -
# 2   Rauðrblade     9     2  Slows Special trigger (cooldown count+1).Adds ...
# 3  Rauðrblade+    13     2  Slows Special trigger (cooldown count+1).Adds ...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,           Name Cooldown                                             Effect  \
# 0  Retribution        3  Grants bonus to damage dealt equal to 30% of d...
# 1    Vengeance        3  Grants bonus to damage dealt equal to 50% of d...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4  ,              Name                                             Effect SP Cost  \
# 0  Darting Blow 1  Grants Spd+2 during combat if unit initiates t...      50
# 1  Darting Blow 2  Grants Spd+4 during combat if unit initiates t...     100
# 2  Darting Blow 3  Grants Spd+6 during combat if unit initiates t...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5      Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      4    A
# 3      -    C
# 4      4    C
# 5      5    C  ]
# Michalis
# [         Name Might Range                                           Effect  \
# 0    Iron Axe     6     1                                                -
# 1   Steel Axe     8     1                                                -
# 2  Silver Axe    11     1                                                -
# 3  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     400       -      5  ,               Name Cooldown  \
# 0   Rising Thunder        5
# 1  Blazing Thunder        5
#
#                                               Effect SP Cost Default Unlock
# 0  Before combat this unit initiates, foes in an ...     150       4      3
# 1  Before combat this unit initiates, foes in an ...     300       -      4  ,              Name                                             Effect  \
# 0   Iote's Shield           Neutralizes "effective against" bonuses.
# 1  Threaten Def 1  Inflicts Def-3 on foes within 2 spaces through...
# 2               C                                     Threaten Def 2
# 3               3                                     Threaten Def 3
#
#                                              SP Cost Unlock Type
# 0                                                200      4    A
# 1                                                 50      -    A
# 2  Inflicts Def-4 on foes within 2 spaces through...    100    A
# 3  Inflicts Def-5 on foes within 2 spaces through...    200    4  ]
# Ninian
# [            Name Might Range  \
# 0    Fire Breath     6     1
# 1   Fire Breath+     8     1
# 2   Light Breath     9     1
# 3  Light Breath+    13     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2  Grants adjacent allies Def/Res+4 through their...     200       -      -
# 3  Grants adjacent allies Def/Res+4 through their...     300       5      -  ,     Name Range                                             Effect SP Cost  \
# 0  Dance     1  Enables target to take another action.Cannot b...     150
#
#   Default Unlock
# 0       5      -  ,               Name                                             Effect SP Cost  \
# 0   Escape Route 1  Enables unit whose own HP is ≤ 30% to warp adj...      60
# 1   Escape Route 2  Enables unit whose own HP is ≤ 40% to warp adj...     120
# 2   Escape Route 3  Enables unit whose own HP is ≤ 50% to warp adj...     240
# 3    Fortify Def 1  Grants adjacent allies Def+2 through their nex...      50
# 4    Fortify Def 2  Grants adjacent allies Def+3 through their nex...     100
# 5  Fortify Dragons  Grants adjacent Dragon allies Def/Res+6 throug...     200
#
#   Unlock Type
# 0      -    B
# 1      -    B
# 2      5    B
# 3      -    C
# 4      -    C
# 5      5    C  ]
# Lilina
# [         Name Might Range Effect SP Cost Default Unlock
# 0        Fire     4     2      -      50       -      -
# 1      Elfire     6     2      -     100       -      -
# 2   Bolganone     9     2      -     200       4      -
# 3  Bolganone+    13     2      -     300       5      5,             Name Cooldown                                             Effect  \
# 0   Rising Flame        5  Before combat this unit initiates, foes in an ...
# 1  Growing Flame        5  Before combat this unit initiates, foes in a w...
#
#   SP Cost Default Unlock
# 0     150       4      -
# 1     300       -      4  ,          Name                                       Effect SP Cost Unlock Type
# 0   Attack +1                                Grants Atk+1.      30      -    A
# 1   Attack +2                                Grants Atk+2.      60      4    A
# 2   Attack +3                                Grants Atk+3.     120      5    A
# 3  Spur Atk 1  Grants adjacent allies Atk+2 during combat.      50      -    C
# 4  Spur Atk 2  Grants adjacent allies Atk+3 during combat.     100      -    C
# 5  Spur Atk 3  Grants adjacent allies Atk+4 during combat.     200      4    C]
# Hawkeye
# [          Name Might Range                                           Effect  \
# 0     Iron Axe     6     1                                                -
# 1    Steel Axe     8     1                                                -
# 2   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      3
# 3     300       5      5  ,             Name Cooldown                                             Effect  \
# 0   Rising Light        5  Before combat this unit initiates, foes in an ...
# 1  Growing Light        5  Before combat this unit initiates, foes in a w...
#
#   SP Cost Default Unlock
# 0     150       4      -
# 1     300       -      4  ,              Name                                             Effect SP Cost  \
# 0    Death Blow 1  Grants Atk+2 during combat if unit initiates t...      50
# 1    Death Blow 2  Grants Atk+4 during combat if unit initiates t...     100
# 2    Death Blow 3  Grants Atk+6 during combat if unit initiates t...     200
# 3  Threaten Atk 1  Inflicts Atk-3 on foes within 2 spaces through...      50
# 4  Threaten Atk 2  Inflicts Atk-4 on foes within 2 spaces through...     100
# 5  Threaten Atk 3  Inflicts Atk-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      -    A
# 1      4    A
# 2      5    A
# 3      -    C
# 4      -    C
# 5      4    C  ]

# %%
#now that all the tables are created and linked to the hero in a dictionary, I can go through each key in the dict
#and make four complete dataframes, weapons, specials, assits, and passives.

# %%
#print(feh_hero_dict['Abel'][0].columns)
#for i in feh_hero_dict['Abel'][0].columns:
#    print(i)

count = 0
for key, value in feh_hero_dict.items():
    if count < 1:
        print(key)
        for each in value:
            print(each.columns[1])
        for each in value:
            print(each.shape)
    count += 1
# Out:
# Robin_(M)
# Might
# Cooldown
# Effect
# (4, 7)
# (2, 6)
# (6, 5)

# %%
def sorted_dataframes(feh_dict):
    weapons = []
    assists = []
    specials = []
    passives = []
    count = 0
    for key, value in feh_dict.items():
        for each in value:
            if each.columns[1] == 'Might':
                #print(each.shape[0])
                #print(each)
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                #print(key_list)
                new_add = each.copy()
                new_add['Hero'] = key_list
                weapons.append(new_add)
            elif each.columns[1] == 'Range':
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                new_add = each.copy()
                new_add['Hero'] = key_list
                assists.append(new_add)
            elif each.columns[1] == 'Cooldown':
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                new_add = each.copy()
                new_add['Hero'] = key_list
                specials.append(new_add)
            elif each.columns[1] == 'Effect':
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                new_add = each.copy()
                new_add['Hero'] = key_list
                passives.append(new_add)
        #print(weapons)
        character_info = []
        if len(weapons) > 0:
            character_info.append(weapons)
        if len(assists) > 0:
            character_info.append(assists)
        if len(specials) > 0:
            character_info.append(specials)
        if len(passives) > 0:
            character_info.append(passives)
        
        #count += 1
        #if count > 0:
        #    break
            
    return(character_info)

                
#add each dataframe to the respective list, also add a new column and fill the column with the name of hero it
#belongs to. one way to do this is use DataFrame.shape[0] with gives you how many rows are in the dataframe.
#make a list that length, and fill it with the key for that dataframe. then DataFrame[key][each]['Hero'] = list
#that will create a column named hero, which all dataframes will have, and add the list as an unique ID


sorted_feh = sorted_dataframes(feh_hero_dict)
print(sorted_feh)
# Out:
# [[         Name Might Range                                       Effect  \
# 0     Thunder     4     2                                            -
# 1   Elthunder     6     2                                            -
# 2   Blárraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Blárraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock       Hero
# 0      50       -      -  Robin_(M)
# 1     100       3      -  Robin_(M)
# 2     200       4      3  Robin_(M)
# 3     300       5      5  Robin_(M)  ,        Name Might Range                                             Effect  \
# 0  Élivágar    14     2  If unit initiates attack, bonuses on foes with...
#
#   SP Cost Default Unlock      Hero
# 0     400       -      -  Veronica  ,              Name Might Range  \
# 0     Iron Dagger     3     2
# 1    Steel Dagger     5     2
# 2   Silver Dagger     7     2
# 3  Silver Dagger+    10     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 2  After combat, inflicts Def/Res-5 on foe throug...     200       4      -
# 3  After combat, inflicts Def/Res-7 on foe throug...     300       5      5
#
#     Hero
# 0  Jakob
# 1  Jakob
# 2  Jakob
# 3  Jakob  ,             Name Might Range  \
# 0    Iron Dagger     3     2
# 1   Steel Dagger     5     2
# 2   Rogue Dagger     4     2
# 3  Rogue Dagger+     7     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 2  After combat, inflicts Def/Res-3 on foe throug...     200       4      3
# 3  After combat, inflicts Def/Res-5 on foe throug...     300       -      5
#
#     Hero
# 0  Gaius
# 1  Gaius
# 2  Gaius
# 3  Gaius  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Effective against dragons. At the start of eve...     400       5      -
#
#      Hero
# 0  Lucina
# 1  Lucina
# 2  Lucina
# 3  Lucina  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Lance     6     1                                  -      50
# 1   Steel Lance     8     1                                  -     100
# 2   Heavy Spear     8     1  Effective against armored units.      200
# 3  Heavy Spear+    12     1  Effective against armored units.      300
#
#   Default Unlock Hero
# 0       -      -  Est
# 1       3      -  Est
# 2       4      3  Est
# 3       -      5  Est  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Siegfried    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Enables counterattack regardless of distance i...     400       -      5
#
#      Hero
# 0  Xander
# 1  Xander
# 2  Xander
# 3  Xander  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Catria
# 1     100       3      -  Catria
# 2     200       4      3  Catria
# 3     300       5      5  Catria  ,          Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2   Brave Bow     4     2  Spd-5. Effective against flying units. Attacks...
# 3  Brave Bow+     7     2  Spd-5. Effective against flying units. Attacks...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Klein
# 1     100       -      -  Klein
# 2     200       4      -  Klein
# 3     300       5      5  Klein  ,            Name Might Range  \
# 0      Iron Axe     6     1
# 1     Steel Axe     8     1
# 2   Emerald Axe     8     1
# 3  Emerald Axe+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#      Hero
# 0  Arthur
# 1  Arthur
# 2  Arthur
# 3  Arthur  ,              Name Might Range  \
# 0     Iron Dagger     3     2
# 1    Steel Dagger     5     2
# 2   Silver Dagger     7     2
# 3  Deathly Dagger    11     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 2  After combat, inflicts Def/Res-5 on foe throug...     200       -      -
# 3  After combat, inflicts Def/Res-7 on foe throug...     400       5      -
#
#      Hero
# 0  Jaffar
# 1  Jaffar
# 2  Jaffar
# 3  Jaffar  ,            Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock    Hero
# 0      50       1      -  Donnel
# 1     100       3      2  Donnel
# 2     200       4      3  Donnel
# 3     300       -      5  Donnel  ,           Name Might Range                                             Effect  \
# 0   Iron Lance     6     1                                                  -
# 1  Steel Lance     8     1                                                  -
# 2  Heavy Spear     8     1                  Effective against armored units.
# 3     Siegmund    16     1  Grants adjacent allies Atk+3 through their nex...
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Ephraim
# 1     100       -      -  Ephraim
# 2     200       -      -  Ephraim
# 3     400       5      -  Ephraim  ,             Name Might Range                                           Effect  \
# 0     Iron Sword     6     1                                                -
# 1    Steel Sword     8     1                                                -
# 2   Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killing Edge+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Lon'qu
# 1     100       3      -  Lon'qu
# 2     200       4      3  Lon'qu
# 3     300       -      5  Lon'qu  ,          Name Might Range                                             Effect  \
# 0        Wind     4     2                                                  -
# 1      Elwind     6     2                                                  -
# 2   Green Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 3  Green Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock                       Hero
# 0      50       -      -  Camilla_(Spring_Festival)
# 1     100       -      -  Camilla_(Spring_Festival)
# 2     200       -      -  Camilla_(Spring_Festival)
# 3     300       5      -  Camilla_(Spring_Festival)  ,          Name Might Range                                       Effect  \
# 0    Iron Axe     6     1                                            -
# 1   Steel Axe     8     1                                            -
# 2   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Barst
# 1     100       3      -  Barst
# 2     200       4      3  Barst
# 3     300       -      5  Barst  ,            Name Might Range                                      Effect  \
# 0    Iron Sword     6     1                                           -
# 1   Steel Sword     8     1                                           -
# 2  Silver Sword    11     1                                           -
# 3       Tyrfing    16     1  Grants Def+4 in battle if unit's HP ≤ 50%.
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Seliph
# 1     100       -      -  Seliph
# 2     200       4      -  Seliph
# 3     400       5      5  Seliph  ,             Name Might Range  \
# 0    Fire Breath     6     1
# 1   Fire Breath+     8     1
# 2   Light Breath     9     1
# 3  Light Breath+    13     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2  Grants adjacent allies Def/Res+4 through their...     200       4      -
# 3  Grants adjacent allies Def/Res+4 through their...     300       5      5
#
#   Hero
# 0  Fae
# 1  Fae
# 2  Fae
# 3  Fae  ,               Name Might Range  \
# 0         Iron Bow     4     2
# 1        Steel Bow     6     2
# 2   Assassin's Bow     7     2
# 3  Assassin's Bow+    11     2
#
#                                               Effect SP Cost Default Unlock  \
# 0                   Effective against flying units.       50       -      -
# 1                   Effective against flying units.      100       3      -
# 2  Effective against flying units. If target has ...     200       4      3
# 3  Effective against flying units. If target has ...     300       5      5
#
#       Hero
# 0  Setsuna
# 1  Setsuna
# 2  Setsuna
# 3  Setsuna  ,          Name Might Range                            Effect SP Cost Default  \
# 0        Wind     4     2                                 -      50       2
# 1      Elwind     6     2                                 -     100       3
# 2   Gronnwolf     6     2  Effective against cavalry units.     200       4
# 3  Gronnwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock       Hero
# 0      -  Robin_(F)
# 1      2  Robin_(F)
# 2      3  Robin_(F)
# 3      5  Robin_(F)  ,           Name Might Range                                             Effect  \
# 0         Wind     4     2                                                  -
# 1       Elwind     6     2                                                  -
# 2   Gronnblade     9     2  Slows Special trigger (cooldown count+1).Adds ...
# 3  Gronnblade+    13     2  Slows Special trigger (cooldown count+1).Adds ...
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Nino
# 1     100       3      -  Nino
# 2     200       4      3  Nino
# 3     300       -      5  Nino  ,           Name Might Range                                             Effect  \
# 0     Iron Bow     4     2                   Effective against flying units.
# 1    Steel Bow     6     2                   Effective against flying units.
# 2   Killer Bow     5     2  Effective against flying units. Accelerates Sp...
# 3  Killer Bow+     9     2  Effective against flying units. Accelerates Sp...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Niles
# 1     100       3      -  Niles
# 2     200       4      3  Niles
# 3     300       -      5  Niles  ,             Name Might Range                                           Effect  \
# 0     Iron Sword     6     1                                                -
# 1    Steel Sword     8     1                                                -
# 2   Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killing Edge+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Navarre
# 1     100       3      -  Navarre
# 2     200       4      3  Navarre
# 3     300       -      5  Navarre  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Fólkvangr    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       2      -
# 1                                                  -     100       -      2
# 2                                                  -     200       -      3
# 3  Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5
#
#       Hero
# 0  Alfonse
# 1  Alfonse
# 2  Alfonse
# 3  Alfonse  ,            Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       2      -  Draug
# 1     100       -      2  Draug
# 2     200       4      3  Draug
# 3     300       5      5  Draug  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Durandal    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Grants Atk+4 during combat if unit initiates a...     400       5      5
#
#       Hero
# 0  Eliwood
# 1  Eliwood
# 2  Eliwood
# 3  Eliwood  ,              Name Might Range  \
# 0        Iron Bow     4     2
# 1       Steel Bow     6     2
# 2   Firesweep Bow     7     2
# 3  Firesweep Bow+    11     2
#
#                                               Effect SP Cost Default Unlock  \
# 0                   Effective against flying units.       50       -      -
# 1                   Effective against flying units.      100       -      -
# 2  Effective against flying units. Unit and enemi...     200       -      -
# 3  Effective against flying units. Unit and enemi...     300       5      -
#
#    Hero
# 0  Faye
# 1  Faye
# 2  Faye
# 3  Faye  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Eckesachs    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Inflicts Def-4 on foes within 2 spaces through...     400       -      5
#
#       Hero
# 0  Zephiel
# 1  Zephiel
# 2  Zephiel
# 3  Zephiel  ,       Name Might Range                            Effect SP Cost Default  \
# 0  Assault    10     2                                 -      50       -
# 1   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#   Unlock      Hero
# 0      -  Lachesis
# 1      4  Lachesis  ,            Name Might Range  \
# 0    Iron Lance     6     1
# 1   Steel Lance     8     1
# 2  Silver Lance    11     1
# 3      Fensalir    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       2      -
# 1                                                  -     100       -      2
# 2                                                  -     200       -      3
# 3  Inflicts Atk-4 on foes within 2 spaces through...     400       -      5
#
#       Hero
# 0  Sharena
# 1  Sharena
# 2  Sharena
# 3  Sharena  ,          Name Might Range                                           Effect  \
# 0    Iron Axe     6     1                                                -
# 1   Steel Axe     8     1                                                -
# 2  Silver Axe    11     1                                                -
# 3  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Minerva
# 1     100       -      -  Minerva
# 2     200       -      -  Minerva
# 3     400       5      -  Minerva  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Mist
# 1     150       -      5  Mist  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Shanna
# 1     100       3      -  Shanna
# 2     200       4      3  Shanna
# 3     300       -      5  Shanna  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Elise
# 1     150       -      -  Elise  ,             Name Might Range Effect SP Cost Default Unlock   Hero
# 0     Iron Lance     6     1      -      50       -      -  Clair
# 1    Steel Lance     8     1      -     100       -      -  Clair
# 2   Silver Lance    11     1      -     200       4      -  Clair
# 3  Silver Lance+    15     1      -     300       5      -  Clair,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       4      -
# 3  Effective against dragons. At the start of eve...     400       5      5
#
#     Hero
# 0  Marth
# 1  Marth
# 2  Marth
# 3  Marth  ,            Name Might Range                                       Effect  \
# 0       Thunder     4     2                                            -
# 1     Elthunder     6     2                                            -
# 2        Thoron     9     2                                            -
# 3  Dire Thunder     9     2  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Olwen
# 1     100       -      -  Olwen
# 2     200       -      -  Olwen
# 3     400       5      -  Olwen  ,             Name Might Range  \
# 0    Iron Dagger     3     2
# 1   Steel Dagger     5     2
# 2   Smoke Dagger     6     2
# 3  Smoke Dagger+     9     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 2  After combat, inflicts Def/Res-4 on foes withi...     200       4      3
# 3  After combat, inflicts Def/Res-6 on foes withi...     300       -      5
#
#     Hero
# 0  Saizo
# 1  Saizo
# 2  Saizo
# 3  Saizo  ,          Name Might Range                            Effect SP Cost Default  \
# 0        Flux     4     2                                 -      50       2
# 1        Ruin     6     2                                 -     100       3
# 2   Rauðrwolf     6     2  Effective against cavalry units.     200       4
# 3  Rauðrwolf+    10     2  Effective against cavalry units.     200       -
#
#   Unlock   Hero
# 0      -  Raigh
# 1      2  Raigh
# 2      3  Raigh
# 3      5  Raigh  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      1  Lissa
# 1     150       -      3  Lissa  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Sol Katti    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  If wielder initiates attack at HP ≤ 50%, any f...     400       5      -
#
#   Hero
# 0  Lyn
# 1  Lyn
# 2  Lyn
# 3  Lyn  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Effective against dragons. At the start of eve...     400       5      -
#
#   Hero
# 0  Alm
# 1  Alm
# 2  Alm
# 3  Alm  ,                 Name Might Range  \
# 0        Fire Breath     6     1
# 1       Fire Breath+     8     1
# 2   Lightning Breath     7     1
# 3  Lightning Breath+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2  Enables counterattack regardless of attacker's...     200       4      3
# 3  Enables counterattack regardless of attacker's...     300       5      5
#
#            Hero
# 0  Tiki_(Adult)
# 1  Tiki_(Adult)
# 2  Tiki_(Adult)
# 3  Tiki_(Adult)  ,          Name Might Range                                       Effect  \
# 0    Iron Axe     6     1                                            -
# 1   Steel Axe     8     1                                            -
# 2   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Raven
# 1     100       -      -  Raven
# 2     200       4      -  Raven
# 3     300       5      5  Raven  ,         Name Might Range                                             Effect  \
# 0       Fire     4     2                                                  -
# 1     Elfire     6     2                                                  -
# 2  Bolganone     9     2                                                  -
# 3  Cymbeline    14     2  Grants adjacent allies Atk+4 through their nex...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Sanaki
# 1     100       -      -  Sanaki
# 2     200       -      -  Sanaki
# 3     400       5      -  Sanaki  ,            Name Might Range                                           Effect  \
# 0    Iron Sword     6     1                                                -
# 1   Steel Sword     8     1                                                -
# 2  Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3   Mystletainn    16     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Eldigan
# 1     100       -      -  Eldigan
# 2     200       -      -  Eldigan
# 3     400       5      -  Eldigan  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Sword     6     1                                  -      50
# 1   Steel Sword     8     1                                  -     100
# 2   Armorslayer     8     1  Effective against armored units.      200
# 3  Armorslayer+    12     1  Effective against armored units.      300
#
#   Default Unlock   Hero
# 0       -      -  Caeda
# 1       -      -  Caeda
# 2       4      -  Caeda
# 3       5      5  Caeda  ,             Name Might Range Effect SP Cost Default Unlock    Hero
# 0     Iron Sword     6     1      -      50       -      -  Laslow
# 1    Steel Sword     8     1      -     100       3      -  Laslow
# 2   Silver Sword    11     1      -     200       4      3  Laslow
# 3  Silver Sword+    15     1      -     300       -      5  Laslow,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       4      -
# 3  Effective against dragons. At the start of eve...     400       5      5
#
#     Hero
# 0  Chrom
# 1  Chrom
# 2  Chrom
# 3  Chrom  ,            Name Might Range  \
# 0      Iron Axe     6     1
# 1     Steel Axe     8     1
# 2   Emerald Axe     8     1
# 3  Emerald Axe+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       2      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#       Hero
# 0  Narcian
# 1  Narcian
# 2  Narcian
# 3  Narcian  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3          Yato    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       4      -
# 3  Grants Spd+4 during combat if unit initiates a...     400       5      5
#
#          Hero
# 0  Corrin_(M)
# 1  Corrin_(M)
# 2  Corrin_(M)
# 3  Corrin_(M)  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Lukas
# 1     100       -      -  Lukas
# 2     200       4      -  Lukas
# 3     300       5      -  Lukas  ,         Name Might Range                            Effect SP Cost Default  \
# 0    Thunder     4     2                                 -      50       -
# 1  Elthunder     6     2                                 -     100       3
# 2   Blárwolf     6     2  Effective against cavalry units.     200       4
# 3  Blárwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock    Hero
# 0      -  Ursula
# 1      -  Ursula
# 2      3  Ursula
# 3      5  Ursula  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Sakura
# 1     150       -      4  Sakura  ,           Name Might Range                                             Effect  \
# 0   Iron Sword     6     1                                                  -
# 1  Steel Sword     8     1                                                  -
# 2   Ruby Sword     8     1  Gives Atk+20% if weapon-triangle advantage, At...
# 3  Ruby Sword+    12     1  Gives Atk+20% if weapon-triangle advantage, At...
#
#   SP Cost Default Unlock   Hero
# 0      50       1      -  Stahl
# 1     100       3      2  Stahl
# 2     200       4      3  Stahl
# 3     300       -      5  Stahl  ,          Name Might Range                                             Effect  \
# 0        Wind     4     2                                                  -
# 1      Elwind     6     2                                                  -
# 2  Rexcalibur     9     2                                                  -
# 3        Naga    14     2  Effective against dragons. Grants Def/Res+2 wh...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Julia
# 1     100       -      -  Julia
# 2     200       -      -  Julia
# 3     400       5      -  Julia  ,               Name Might Range  \
# 0       Iron Lance     6     1
# 1      Steel Lance     8     1
# 2   Sapphire Lance     8     1
# 3  Sapphire Lance+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       1      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#     Hero
# 0  Sully
# 1  Sully
# 2  Sully
# 3  Sully  ,              Name Might Range  \
# 0     Iron Dagger     3     2
# 1    Steel Dagger     5     2
# 2   Poison Dagger     2     2
# 3  Poison Dagger+     5     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 2  Effective against infantry units. Infantry foe...     200       4      -
# 3  Effective against infantry units. Infantry foe...     300       5      5
#
#      Hero
# 0  Kagero
# 1  Kagero
# 2  Kagero
# 3  Kagero  ,            Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Cain
# 1     100       -      -  Cain
# 2     200       4      -  Cain
# 3     300       5      5  Cain  ,           Name Might Range                                       Effect  \
# 0         Flux     4     2                                            -
# 1         Ruin     6     2                                            -
# 2   Rauðrraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Rauðrraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Henry
# 1     100       3      -  Henry
# 2     200       4      3  Henry
# 3     300       -      5  Henry  ,                 Name Might Range  \
# 0        Fire Breath     6     1
# 1       Fire Breath+     8     1
# 2   Lightning Breath     7     1
# 3  Lightning Breath+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2  Enables counterattack regardless of attacker's...     200       4      -
# 3  Enables counterattack regardless of attacker's...     300       5      5
#
#    Hero
# 0  Nowi
# 1  Nowi
# 2  Nowi
# 3  Nowi  ,             Name Might Range Effect SP Cost Default Unlock    Hero
# 0     Iron Sword     6     1      -      50       1      -  Olivia
# 1    Steel Sword     8     1      -     100       3      2  Olivia
# 2   Silver Sword    11     1      -     200       4      3  Olivia
# 3  Silver Sword+    15     1      -     300       -      5  Olivia,           Name Might Range                            Effect SP Cost Default  \
# 0     Iron Bow     4     2  Effective against flying units.       50       1
# 1    Steel Bow     6     2  Effective against flying units.      100       3
# 2   Silver Bow     9     2  Effective against flying units.      200       4
# 3  Silver Bow+    13     2  Effective against flying units.      300       -
#
#   Unlock    Hero
# 0      -  Virion
# 1      2  Virion
# 2      3  Virion
# 3      5  Virion  ,         Name Might Range                             Effect SP Cost Default  \
# 0   Iron Axe     6     1                                  -      50       -
# 1  Steel Axe     8     1                                  -     100       3
# 2     Hammer     8     1  Effective against armored units.      200       4
# 3    Hammer+    12     1  Effective against armored units.      200       5
#
#   Unlock     Hero
# 0      -  Cherche
# 1      -  Cherche
# 2      3  Cherche
# 3      5  Cherche  ,          Name Might Range                                       Effect  \
# 0    Iron Axe     6     1                                            -
# 1   Steel Axe     8     1                                            -
# 2   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Camilla
# 1     100       -      -  Camilla
# 2     200       4      -  Camilla
# 3     300       5      5  Camilla  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#   SP Cost Default Unlock  Hero
# 0      50       -      1  Wrys
# 1     150       -      3  Wrys  ,           Name Might Range                                           Effect  \
# 0     Iron Axe     6     1                                                -
# 1    Steel Axe     8     1                                                -
# 2   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Beruka
# 1     100       3      -  Beruka
# 2     200       4      3  Beruka
# 3     300       5      5  Beruka  ,          Name Might Range                                            Effect  \
# 0    Iron Axe     6     1                                                 -
# 1   Steel Axe     8     1                                                 -
# 2  Silver Axe    11     1                                                 -
# 3      Nóatún    16     1  Unit may move adjacent to any ally when HP ≤ 40%
#
#   SP Cost Default Unlock  Hero
# 0      50       2      -  Anna
# 1     100       -      2  Anna
# 2     200       -      3  Anna
# 3     400       -      5  Anna  ,          Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2  Silver Bow     9     2                   Effective against flying units.
# 3  Fujin Yumi    14     2  Effective against flying units. Unit can pass ...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Takumi
# 1     100       -      -  Takumi
# 2     200       -      -  Takumi
# 3     400       5      -  Takumi  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock       Hero
# 0      50       -      -  Gwendolyn
# 1     100       3      -  Gwendolyn
# 2     200       4      3  Gwendolyn
# 3     300       -      5  Gwendolyn  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Raijinto    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Enables counterattack regardless of distance i...     400       5      -
#
#     Hero
# 0  Ryoma
# 1  Ryoma
# 2  Ryoma
# 3  Ryoma  ,            Name Might Range                                       Effect  \
# 0       Thunder     4     2                                            -
# 1     Elthunder     6     2                                            -
# 2        Thoron     9     2                                            -
# 3  Dire Thunder     9     2  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock       Hero
# 0      50       -      -  Reinhardt
# 1     100       -      -  Reinhardt
# 2     200       4      -  Reinhardt
# 3     400       5      5  Reinhardt  ,               Name Might Range  \
# 0       Iron Lance     6     1
# 1      Steel Lance     8     1
# 2   Sapphire Lance     8     1
# 3  Sapphire Lance+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       1      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       5      5
#
#      Hero
# 0  Subaki
# 1  Subaki
# 2  Subaki
# 3  Subaki  ,           Name Might Range                                             Effect  \
# 0   Iron Sword     6     1                                                  -
# 1  Steel Sword     8     1                                                  -
# 2   Ruby Sword     8     1  Gives Atk+20% if weapon-triangle advantage, At...
# 3  Ruby Sword+    12     1  Gives Atk+20% if weapon-triangle advantage, At...
#
#   SP Cost Default Unlock    Hero
# 0      50       1      -  Hinata
# 1     100       3      2  Hinata
# 2     200       4      3  Hinata
# 3     300       -      5  Hinata  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Lance     6     1                                  -      50
# 1   Steel Lance     8     1                                  -     100
# 2   Heavy Spear     8     1  Effective against armored units.      200
# 3  Heavy Spear+    12     1  Effective against armored units.      300
#
#   Default Unlock   Hero
# 0       -      -  Oboro
# 1       3      -  Oboro
# 2       4      3  Oboro
# 3       -      5  Oboro  ,           Name Might Range                                       Effect  \
# 0   Iron Sword     6     1                                            -
# 1  Steel Sword     8     1                                            -
# 2       Wo Dao     9     1  Grants +10 to damage when Special triggers.
# 3      Wo Dao+    13     1  Grants +10 to damage when Special triggers.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Karel
# 1     100       -      -  Karel
# 2     200       -      -  Karel
# 3     300       5      -  Karel  ,       Name Might Range                            Effect SP Cost Default  \
# 0  Assault    10     2                                 -      50       -
# 1   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#   Unlock   Hero
# 0      -  Serra
# 1      3  Serra  ,          Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2   Brave Bow     4     2  Spd-5. Effective against flying units. Attacks...
# 3  Brave Bow+     7     2  Spd-5. Effective against flying units. Attacks...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Gordin
# 1     100       3      -  Gordin
# 2     200       4      3  Gordin
# 3     300       5      5  Gordin  ,        Name Might Range                                             Effect  \
# 0  Gradivus    16     1  Enables counterattack regardless of distance i...
#
#   SP Cost Default Unlock   Hero
# 0     400       -      -  Camus  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Lance     6     1                                  -      50
# 1   Steel Lance     8     1                                  -     100
# 2   Heavy Spear     8     1  Effective against armored units.      200
# 3  Heavy Spear+    12     1  Effective against armored units.      300
#
#   Default Unlock     Hero
# 0       -      -  Florina
# 1       3      -  Florina
# 2       4      3  Florina
# 3       -      5  Florina  ,       Name Might Range Effect SP Cost Default Unlock    Hero
# 0     Flux     4     2      -      50       1      -  Sophia
# 1     Ruin     6     2      -     100       3      2  Sophia
# 2   Fenrir     9     2      -     200       4      3  Sophia
# 3  Fenrir+    13     2      -     300       -      5  Sophia,           Name Might Range Effect SP Cost Default Unlock    Hero
# 0     Iron Axe     6     1      -      50       1      -  Gunter
# 1    Steel Axe     8     1      -     100       3      2  Gunter
# 2   Silver Axe    11     1      -     200       4      3  Gunter
# 3  Silver Axe+    15     1      -     300       -      5  Gunter,            Name Might Range Effect SP Cost Default Unlock          Hero
# 0   Fire Breath     6     1      -      50       -      -  Tiki_(Young)
# 1  Fire Breath+     8     1      -     100       -      -  Tiki_(Young)
# 2   Flametongue    11     1      -     200       -      -  Tiki_(Young)
# 3  Flametongue+    15     1      -     300       5      -  Tiki_(Young),             Name Might Range                                        Effect  \
# 0     Iron Sword     6     1                                             -
# 1    Steel Sword     8     1                                             -
# 2   Silver Sword    11     1                                             -
# 3  Binding Blade    16     1  Grants Def/Res+2 when this unit is attacked.
#
#   SP Cost Default Unlock Hero
# 0      50       -      -  Roy
# 1     100       -      -  Roy
# 2     200       4      -  Roy
# 3     400       5      5  Roy  ,           Name Might Range                                       Effect  \
# 0         Wind     4     2                                            -
# 1       Elwind     6     2                                            -
# 2   Gronnraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Gronnraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock     Hero
# 0      50       1      -  Cecilia
# 1     100       3      2  Cecilia
# 2     200       4      3  Cecilia
# 3     300       -      5  Cecilia  ,         Name Might Range                                             Effect  \
# 0    Thunder     4     2                                                  -
# 1  Elthunder     6     2                                                  -
# 2   Blue Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 3  Blue Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock                      Hero
# 0      50       -      -  Lucina_(Spring_Festival)
# 1     100       -      -  Lucina_(Spring_Festival)
# 2     200       -      -  Lucina_(Spring_Festival)
# 3     300       5      -  Lucina_(Spring_Festival)  ,           Name Might Range                                           Effect  \
# 0     Iron Axe     6     1                                                -
# 1    Steel Axe     8     1                                                -
# 2   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Sheena
# 1     100       -      -  Sheena
# 2     200       4      -  Sheena
# 3     300       5      5  Sheena  ,       Name Might Range                                            Effect  \
# 0  Assault    10     2                                                 -
# 1     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      3  Azama
# 1     150       -      3  Azama  ,          Name Might Range                                             Effect  \
# 0  Valaskjálf    14     2  Enables unit at ≤ 50% HP to strike first, even...
#
#   SP Cost Default Unlock   Hero
# 0     400       -      -  Bruno  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Sword     6     1                                  -      50
# 1   Steel Sword     8     1                                  -     100
# 2   Armorslayer     8     1  Effective against armored units.      200
# 3  Armorslayer+    12     1  Effective against armored units.      300
#
#   Default Unlock    Hero
# 0       -      -  Selena
# 1       3      -  Selena
# 2       4      3  Selena
# 3       5      5  Selena  ,           Name Might Range Effect SP Cost Default Unlock   Hero
# 0         Wind     4     2      -      50       -      -  Soren
# 1       Elwind     6     2      -     100       -      -  Soren
# 2   Rexcalibur     9     2      -     200       -      -  Soren
# 3  Rexcalibur+    13     2      -     300       5      -  Soren,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3       Ragnell    16     1
# ...
# 1      60      4    A  Felicia
# 2     120      5    A  Felicia
# 3      50      1    C  Felicia
# 4     100      2    C  Felicia
# 5     200      4    C  Felicia  ,          Name                                             Effect  \
# 0   Drag Back  If unit initiates attack, the unit moves 1 spa...
# 1  Hone Spd 1  Grants adjacent allies Spd+2 through their nex...
# 2           C                                         Hone Spd 2
# 3           -                                         Hone Spd 3
#
#                                              SP Cost Unlock Type    Hero
# 0                                                150      4    B  Eirika
# 1                                                 50      -    B  Eirika
# 2  Grants adjacent allies Spd+3 through their nex...    100    B  Eirika
# 3  Grants adjacent allies Spd+4 through their nex...    200    4  Eirika  ,              Name                                             Effect SP Cost  \
# 0  Armored Blow 1  Grants Def+2 during combat if unit initiates t...      50
# 1  Armored Blow 2  Grants Def+4 during combat if unit initiates t...     100
# 2  Armored Blow 3  Grants Def+6 during combat if unit initiates t...     200
# 3         Guard 1  If unit's HP is 100% at start of combat, enemy...      50
# 4         Guard 2  If unit's HP is ≥ 90% at start of combat, enem...     100
# 5         Guard 3  If unit's HP is ≥ 80% at start of combat, enem...     200
#
#   Unlock Type     Hero
# 0      -    A  Titania
# 1      -    A  Titania
# 2      5    A  Titania
# 3      -    B  Titania
# 4      -    B  Titania
# 5      5    B  Titania  ,          Name                                             Effect SP Cost  \
# 0  Seal Res 1  After combat, foe suffers Res-3 through its ne...      40
# 1  Seal Res 2  After combat, foe suffers Res-5 through its ne...      80
# 2  Seal Res 3  After combat, foe suffers Res-7 through its ne...     160
# 3  Hone Atk 1  Grants adjacent allies Atk+2 through their nex...      50
# 4  Hone Atk 2  Grants adjacent allies Atk+3 through their nex...     100
# 5  Hone Atk 3  Grants adjacent allies Atk+4 through their nex...     200
#
#   Unlock Type        Hero
# 0      3    B  Corrin_(F)
# 1      4    B  Corrin_(F)
# 2      5    B  Corrin_(F)
# 3      -    C  Corrin_(F)
# 4      3    C  Corrin_(F)
# 5      4    C  Corrin_(F)  ,             Name                                             Effect SP Cost  \
# 0  Defiant Def 1  Grants Def+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Def 2  Grants Def+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Def 3  Grants Def+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Hone Spd 1  Grants adjacent allies Spd+2 through their nex...      50
# 4     Hone Spd 2  Grants adjacent allies Spd+3 through their nex...     100
# 5    Hone Fliers  Grants adjacent flying allies Atk/Spd+6 throug...     200
#
#   Unlock Type    Hero
# 0      -    A  Hinoka
# 1      -    A  Hinoka
# 2      5    A  Hinoka
# 3      -    C  Hinoka
# 4      -    C  Hinoka
# 5      5    C  Hinoka  ,             Name         Effect SP Cost Unlock Type     Hero
# 0  Resistance +1  Grants Res+1.      30      3    A  Clarine
# 1  Resistance +2  Grants Res+2.      60      4    A  Clarine
# 2  Resistance +3  Grants Res+3.     120      5    A  Clarine,               Name                                             Effect  \
# 0  Distant Counter  Enables unit to counterattack regardless of di...
# 1       Spur Atk 1        Grants adjacent allies Atk+2 during combat.
# 2                C                                         Spur Atk 2
# 3                -                                         Goad Armor
#
#                                              SP Cost Unlock Type    Hero
# 0                                                300      5    A  Hector
# 1                                                 50      -    A  Hector
# 2        Grants adjacent allies Atk+3 during combat.    100    A  Hector
# 3  Grants armored allies within 2 spaces Spd/Atk+...    200    5  Hector  ,        Name                                            Effect SP Cost Unlock  \
# 0  Speed +1                                     Grants Spd+1.      30      -
# 1  Speed +2                                     Grants Spd+2.      60      3
# 2  Speed +3                                     Grants Spd+3.     120      4
# 3    Pass 1  Units can pass through foes if its own HP ≥ 75%.      50      3
# 4    Pass 2  Units can pass through foes if its own HP ≥ 50%.     100      4
# 5    Pass 3  Units can pass through foes if its own HP ≥ 25%.     200      5
#
#   Type Hero
# 0    A  Fir
# 1    A  Fir
# 2    A  Fir
# 3    B  Fir
# 4    B  Fir
# 5    B  Fir  ,              Name                                             Effect SP Cost  \
# 0           HP +3                               Grants +3 to max HP.      40
# 1           HP +4                               Grants +4 to max HP.      80
# 2           HP +5                               Grants +5 to max HP.     160
# 3  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...      50
# 4  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...     100
# 5  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...     200
#
#   Unlock Type  Hero
# 0      -    A  Abel
# 1      4    A  Abel
# 2      5    A  Abel
# 3      -    B  Abel
# 4      -    B  Abel
# 5      4    B  Abel  ,             Name                                             Effect SP Cost  \
# 0       Speed +1                                      Grants Spd+1.      30
# 1       Speed +2                                      Grants Spd+2.      60
# 2       Speed +3                                      Grants Spd+3.     120
# 3  Fortify Res 1  Grants adjacent allies Res+2 through their nex...      50
# 4  Fortify Res 2  Grants adjacent allies Res+3 through their nex...     100
# 5  Fortify Res 3  Grants adjacent allies Res+4 through their nex...     200
#
#   Unlock Type   Hero
# 0      -    A  Linde
# 1      -    A  Linde
# 2      5    A  Linde
# 3      -    C  Linde
# 4      -    C  Linde
# 5      5    C  Linde  ,          Name                                       Effect SP Cost Unlock  \
# 0       HP +3                         Grants +3 to max HP.      40      -
# 1       HP +4                         Grants +4 to max HP.      80      4
# 2       HP +5                         Grants +5 to max HP.     160      5
# 3  Spur Res 1  Grants adjacent allies Res+2 during combat.      50      -
# 4  Spur Res 2  Grants adjacent allies Res+3 during combat.     100      -
# 5  Spur Res 3  Grants adjacent allies Res+4 during combat.     200      4
#
#   Type    Hero
# 0    A  Merric
# 1    A  Merric
# 2    A  Merric
# 3    C  Merric
# 4    C  Merric
# 5    C  Merric  ,              Name                                             Effect  \
# 0  Live for Honor  If unit survives, get 1.5x normal badges from ...
# 1   Fortify Def 1  Grants adjacent allies Def+2 through their nex...
# 2               C                                      Fortify Def 2
# 3               -                                      Fortify Def 3
#
#                                              SP Cost Unlock Type  \
# 0                                                100      5    B
# 1                                                 50      -    B
# 2  Grants adjacent allies Def+3 through their nex...    100    B
# 3  Grants adjacent allies Def+4 through their nex...    200    5
#
#                        Hero
# 0  Xander_(Spring_Festival)
# 1  Xander_(Spring_Festival)
# 2  Xander_(Spring_Festival)
# 3  Xander_(Spring_Festival)  ,          Name                                             Effect SP Cost  \
# 0  Seal Atk 1  After combat, foe suffers Atk-3 through its ne...      40
# 1  Seal Atk 2  After combat, foe suffers Atk-5 through its ne...      80
# 2  Seal Atk 3  After combat, foe suffers Atk-7 through its ne...     160
# 3  Spur Spd 1        Grants adjacent allies Spd+2 during combat.      50
# 4  Spur Spd 2        Grants adjacent allies Spd+3 during combat.     100
# 5  Spur Spd 3        Grants adjacent allies Spd+4 during combat.     200
#
#   Unlock Type    Hero
# 0      -    B  Jeorge
# 1      -    B  Jeorge
# 2      4    B  Jeorge
# 3      -    C  Jeorge
# 4      4    C  Jeorge
# 5      5    C  Jeorge  ,                Name                                             Effect  \
# 0        Defense +1                                      Grants Def+1.
# 1     Attack Def +1                                  Grants Atk/Def+1.
# 2     Attack Def +2                                  Grants Atk/Def+2.
# 3  Axe Experience 1  If unit survives, unit gets 1.5x EXP.(If simil...
# 4  Axe Experience 2  If unit survives, all axe users on team get 1....
# 5  Axe Experience 3  If unit survives, all axe users on team get 2x...
#
#   SP Cost Unlock Type                     Hero
# 0      30      -    A  Chrom_(Spring_Festival)
# 1      80      -    A  Chrom_(Spring_Festival)
# 2     160      5    A  Chrom_(Spring_Festival)
# 3      50      -    C  Chrom_(Spring_Festival)
# 4     100      -    C  Chrom_(Spring_Festival)
# 5     200      5    C  Chrom_(Spring_Festival)  ,               Name                                             Effect SP Cost  \
# 0    Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1    Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2    Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3  R Tomebreaker 1  If unit's HP ≥ 90% in combat against a red tom...      50
# 4  R Tomebreaker 2  If unit's HP ≥ 70% in combat against a red tom...     100
# 5  R Tomebreaker 3  If unit's HP ≥ 50% in combat against a red tom...     200
#
#   Unlock Type  Hero
# 0      3    A  Odin
# 1      4    A  Odin
# 2      5    A  Odin
# 3      -    B  Odin
# 4      3    B  Odin
# 5      4    B  Odin  ,     Name                Effect SP Cost Unlock Type    Hero
# 0  HP +3  Grants +3 to max HP.      40      -    A  Lucius
# 1  HP +4  Grants +4 to max HP.      80      4    A  Lucius
# 2  HP +5  Grants +5 to max HP.     160      5    A  Lucius,                Name                                             Effect  \
# 0  Triangle Adept 1  Gives Atk+10% if weapon-triangle advantage, At...
# 1  Triangle Adept 2  Gives Atk+15% if weapon-triangle advantage, At...
# 2  Triangle Adept 3  Gives Atk+20% if weapon-triangle advantage, At...
# 3            Pass 1   Units can pass through foes if its own HP ≥ 75%.
# 4            Pass 2   Units can pass through foes if its own HP ≥ 50%.
# 5            Pass 3   Units can pass through foes if its own HP ≥ 25%.
#
#   SP Cost Unlock Type      Hero
# 0      50      -    A  Cordelia
# 1     100      4    A  Cordelia
# 2     200      5    A  Cordelia
# 3      50      -    B  Cordelia
# 4     100      -    B  Cordelia
# 5     200      4    B  Cordelia  ,             Name                                             Effect SP Cost  \
# 0  Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Spur Atk 1        Grants adjacent allies Atk+2 during combat.      50
# 4     Spur Atk 2        Grants adjacent allies Atk+3 during combat.     100
# 5     Spur Atk 3        Grants adjacent allies Atk+4 during combat.     200
#
#   Unlock Type  Hero
# 0      -    A  Ogma
# 1      -    A  Ogma
# 2      4    A  Ogma
# 3      -    C  Ogma
# 4      4    C  Ogma
# 5      5    C  Ogma  ,                Name                                             Effect  \
# 0  Life and Death 1               Grants Atk/Spd+3.Inflicts Def/Res-3.
# 1  Life and Death 2               Grants Atk/Spd+4.Inflicts Def/Res-4.
# 2  Life and Death 3               Grants Atk/Spd+5.Inflicts Def/Res-5.
# 3        Obstruct 1  Prevents foes from moving through adjacent spa...
# 4        Obstruct 2  Prevents foes from moving through adjacent spa...
# 5        Obstruct 3  Prevents foes from moving through adjacent spa...
#
#   SP Cost Unlock Type  Hero
# 0      50      3    A  Hana
# 1     100      4    A  Hana
# 2     200      5    A  Hana
# 3      50      1    B  Hana
# 4     100      2    B  Hana
# 5     200      4    B  Hana  ,              Name                                             Effect SP Cost  \
# 0  Darting Blow 1  Grants Spd+2 during combat if unit initiates t...      50
# 1  Darting Blow 2  Grants Spd+4 during combat if unit initiates t...     100
# 2  Darting Blow 3  Grants Spd+6 during combat if unit initiates t...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5      Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type    Hero
# 0      -    A  Tharja
# 1      -    A  Tharja
# 2      4    A  Tharja
# 3      -    C  Tharja
# 4      4    C  Tharja
# 5      5    C  Tharja  ,              Name                                             Effect  \
# 0   Iote's Shield           Neutralizes "effective against" bonuses.
# 1  Threaten Def 1  Inflicts Def-3 on foes within 2 spaces through...
# 2               C                                     Threaten Def 2
# 3               3                                     Threaten Def 3
#
#                                              SP Cost Unlock Type      Hero
# 0                                                200      4    A  Michalis
# 1                                                 50      -    A  Michalis
# 2  Inflicts Def-4 on foes within 2 spaces through...    100    A  Michalis
# 3  Inflicts Def-5 on foes within 2 spaces through...    200    4  Michalis  ,               Name                                             Effect SP Cost  \
# 0   Escape Route 1  Enables unit whose own HP is ≤ 30% to warp adj...      60
# 1   Escape Route 2  Enables unit whose own HP is ≤ 40% to warp adj...     120
# 2   Escape Route 3  Enables unit whose own HP is ≤ 50% to warp adj...     240
# 3    Fortify Def 1  Grants adjacent allies Def+2 through their nex...      50
# 4    Fortify Def 2  Grants adjacent allies Def+3 through their nex...     100
# 5  Fortify Dragons  Grants adjacent Dragon allies Def/Res+6 throug...     200
#
#   Unlock Type    Hero
# 0      -    B  Ninian
# 1      -    B  Ninian
# 2      5    B  Ninian
# 3      -    C  Ninian
# 4      -    C  Ninian
# 5      5    C  Ninian  ,          Name                                       Effect SP Cost Unlock  \
# 0   Attack +1                                Grants Atk+1.      30      -
# 1   Attack +2                                Grants Atk+2.      60      4
# 2   Attack +3                                Grants Atk+3.     120      5
# 3  Spur Atk 1  Grants adjacent allies Atk+2 during combat.      50      -
# 4  Spur Atk 2  Grants adjacent allies Atk+3 during combat.     100      -
# 5  Spur Atk 3  Grants adjacent allies Atk+4 during combat.     200      4
#
#   Type    Hero
# 0    A  Lilina
# 1    A  Lilina
# 2    A  Lilina
# 3    C  Lilina
# 4    C  Lilina
# 5    C  Lilina  ,              Name                                             Effect SP Cost  \
# 0    Death Blow 1  Grants Atk+2 during combat if unit initiates t...      50
# 1    Death Blow 2  Grants Atk+4 during combat if unit initiates t...     100
# 2    Death Blow 3  Grants Atk+6 during combat if unit initiates t...     200
# 3  Threaten Atk 1  Inflicts Atk-3 on foes within 2 spaces through...      50
# 4  Threaten Atk 2  Inflicts Atk-4 on foes within 2 spaces through...     100
# 5  Threaten Atk 3  Inflicts Atk-5 on foes within 2 spaces through...     200
#
#   Unlock Type     Hero
# 0      -    A  Hawkeye
# 1      4    A  Hawkeye
# 2      5    A  Hawkeye
# 3      -    C  Hawkeye
# 4      -    C  Hawkeye
# 5      4    C  Hawkeye  ]]

# %%
print(len(sorted_feh[3]))
# Out:
# 125

# %%
print(feh_hero_dict['Abel'])
# Out:
# [           Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,              Name Cooldown                                             Effect  \
# 0  Holy Vestments        3  Reduces damage inflicted by attacks from foes ...
# 1           Aegis        3  Reduces damage inflicted by attacks from foes ...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4  ,              Name                                             Effect SP Cost  \
# 0           HP +3                               Grants +3 to max HP.      40
# 1           HP +4                               Grants +4 to max HP.      80
# 2           HP +5                               Grants +5 to max HP.     160
# 3  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...      50
# 4  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...     100
# 5  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...     200
#
#   Unlock Type
# 0      -    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      -    B
# 5      4    B  ]

# %%
def concat_df_list(skill):
    skill_df = skill[0]
    for df in skill[1:]:
        skill_df = pd.concat([skill_df, df], ignore_index=True)
    return skill_df
weapons_df_unsorted = concat_df_list(sorted_feh[0])
w_df = weapons_df_unsorted.copy()
#print(w_df.index.values)
w_df['IndexCol'] = w_df.index.values
w_df = w_df.sort_values(['Hero', 'IndexCol'])
print(w_df)
#print(weapons_df)
#weap_alphabetical = weapons_df.sort_values('Hero')
#print(weap_alphabetical)
# Out:
#                 Name Might Range  \
# 417       Iron Lance     6     1
# 418      Steel Lance     8     1
# 419      Brave Lance     5     1
# 420     Brave Lance+     8     1
# 89        Iron Sword     6     1
# 90       Steel Sword     8     1
# 91      Silver Sword    11     1
# 92         Fólkvangr    16     1
# 153       Iron Sword     6     1
# 154      Steel Sword     8     1
# 155     Silver Sword    11     1
# 156         Falchion    16     1
# 253         Iron Axe     6     1
# 254        Steel Axe     8     1
# 255       Silver Axe    11     1
# 256           Nóatún    16     1
# 33          Iron Axe     6     1
# 34         Steel Axe     8     1
# 35       Emerald Axe     8     1
# 36      Emerald Axe+    12     1
# 328          Assault    10     2
# 329             Pain     3     2
# 343       Iron Lance     6     1
# 344      Steel Lance     8     1
# 345   Sapphire Lance     8     1
# 346  Sapphire Lance+    12     1
# 57          Iron Axe     6     1
# 58         Steel Axe     8     1
# 59         Brave Axe     5     1
# 60        Brave Axe+     8     1
# ..               ...   ...   ...
# 309     Fire Breath+     8     1
# 310      Flametongue    11     1
# 311     Flametongue+    15     1
# 395         Iron Axe     6     1
# 396        Steel Axe     8     1
# 397      Emerald Axe     8     1
# 398     Emerald Axe+    12     1
# 197          Thunder     4     2
# 198        Elthunder     6     2
# 199         Blárwolf     6     2
# 200        Blárwolf+    10     2
# 4           Élivágar    14     2
# 235         Iron Bow     4     2
# 236        Steel Bow     6     2
# 237       Silver Bow     9     2
# 238      Silver Bow+    13     2
# 247          Assault    10     2
# 248             Slow     5     2
# 21        Iron Sword     6     1
# 22       Steel Sword     8     1
# 23      Silver Sword    11     1
# 24         Siegfried    16     1
# 429       Iron Lance     6     1
# 430      Steel Lance     8     1
# 431     Carrot Lance     9     1
# 432    Carrot Lance+    13     1
# 105       Iron Sword     6     1
# 106      Steel Sword     8     1
# 107     Silver Sword    11     1
# 108        Eckesachs    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 417                                                  -      50       -      -
# 418                                                  -     100       -      -
# 419        Spd-5. Attack twice when initiating combat.     200       4      -
# 420        Spd-5. Attack twice when initiating combat.     300       5      5
# 89                                                   -      50       2      -
# 90                                                   -     100       -      2
# 91                                                   -     200       -      3
# 92   Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5
# 153                                                  -      50       -      -
# 154                                                  -     100       -      -
# 155                                                  -     200       -      -
# 156  Effective against dragons. At the start of eve...     400       5      -
# 253                                                  -      50       2      -
# 254                                                  -     100       -      2
# 255                                                  -     200       -      3
# 256   Unit may move adjacent to any ally when HP ≤ 40%     400       -      5
# 33                                                   -      50       -      -
# 34                                                   -     100       3      -
# 35   Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 36   Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
# 328                                                  -      50       -      3
# 329   Inflicts 10 damage on targeted foe after combat.     150       -      3
# 343                                                  -      50       -      -
# 344                                                  -     100       -      -
# 345  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 346  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
# 57                                                   -      50       -      -
# 58                                                   -     100       3      -
# 59         Spd-5. Attack twice when initiating combat.     200       4      3
# 60         Spd-5. Attack twice when initiating combat.     300       -      5
# ..                                                 ...     ...     ...    ...
# 309                                                  -     100       -      -
# 310                                                  -     200       -      -
# 311                                                  -     300       5      -
# 395                                                  -      50       -      -
# 396                                                  -     100       -      -
# 397  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 398  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
# 197                                                  -      50       -      -
# 198                                                  -     100       3      -
# 199                   Effective against cavalry units.     200       4      3
# 200                   Effective against cavalry units.     300       -      5
# 4    If unit initiates attack, bonuses on foes with...     400       -      -
# 235                   Effective against flying units.       50       1      -
# 236                   Effective against flying units.      100       3      2
# 237                   Effective against flying units.      200       4      3
# 238                   Effective against flying units.      300       -      5
# 247                                                  -      50       -      1
# 248  After any combat, inflicts Spd-6 on foe throug...     150       -      3
# 21                                                   -      50       -      -
# 22                                                   -     100       3      -
# 23                                                   -     200       4      3
# 24   Enables counterattack regardless of distance i...     400       -      5
# 429                                                  -      50       -      -
# 430                                                  -     100       -      -
# 431  If unit initiates attack, unit recovers 4 HP a...     200       -      -
# 432  If unit initiates attack, unit recovers 4 HP a...     300       5      -
# 105                                                  -      50       -      -
# 106                                                  -     100       3      -
# 107                                                  -     200       4      3
# 108  Inflicts Def-4 on foes within 2 spaces through...     400       -      5
#
#                          Hero  IndexCol
# 417                      Abel       417
# 418                      Abel       418
# 419                      Abel       419
# 420                      Abel       420
# 89                    Alfonse        89
# 90                    Alfonse        90
# 91                    Alfonse        91
# 92                    Alfonse        92
# 153                       Alm       153
# 154                       Alm       154
# 155                       Alm       155
# 156                       Alm       156
# 253                      Anna       253
# 254                      Anna       254
# 255                      Anna       255
# 256                      Anna       256
# 33                     Arthur        33
# 34                     Arthur        34
# 35                     Arthur        35
# 36                     Arthur        36
# 328                     Azama       328
# 329                     Azama       329
# 343                     Azura       343
# 344                     Azura       344
# 345                     Azura       345
# 346                     Azura       346
# 57                      Barst        57
# 58                      Barst        58
# 59                      Barst        59
# 60                      Barst        60
# ..                        ...       ...
# 309              Tiki_(Young)       309
# 310              Tiki_(Young)       310
# 311              Tiki_(Young)       311
# 395                   Titania       395
# 396                   Titania       396
# 397                   Titania       397
# 398                   Titania       398
# 197                    Ursula       197
# 198                    Ursula       198
# 199                    Ursula       199
# 200                    Ursula       200
# 4                    Veronica         4
# 235                    Virion       235
# 236                    Virion       236
# 237                    Virion       237
# 238                    Virion       238
# 247                      Wrys       247
# 248                      Wrys       248
# 21                     Xander        21
# 22                     Xander        22
# 23                     Xander        23
# 24                     Xander        24
# 429  Xander_(Spring_Festival)       429
# 430  Xander_(Spring_Festival)       430
# 431  Xander_(Spring_Festival)       431
# 432  Xander_(Spring_Festival)       432
# 105                   Zephiel       105
# 106                   Zephiel       106
# 107                   Zephiel       107
# 108                   Zephiel       108
#
# [479 rows x 9 columns]

# %%
def concat_and_sort(skill):
    skill_df = skill[0]
    for df in skill[1:]:
        skill_df = pd.concat([skill_df, df], ignore_index=True)
    skill_df['IndexCol'] = skill_df.index.values
    skill_df = skill_df.sort_values(['Hero', 'IndexCol'])
    return skill_df
weapons_df = concat_and_sort(sorted_feh[0])
assits_df = concat_and_sort(sorted_feh[1])
specials_df = concat_and_sort(sorted_feh[2])
passives_df = concat_and_sort(sorted_feh[3])
print(weapons_df.head(4))
print(assits_df.head(8))
print(specials_df.head(8))
print(passives_df.head(8))
# Out:
#              Name Might Range                                       Effect  \
# 417    Iron Lance     6     1                                            -
# 418   Steel Lance     8     1                                            -
# 419   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 420  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock  Hero  IndexCol
# 417      50       -      -  Abel       417
# 418     100       -      -  Abel       418
# 419     200       4      -  Abel       419
# 420     300       5      5  Abel       420
#            Name Range                                             Effect  \
# 3          Swap     1                 Swap places with an adjacent ally.
# 53         Heal     1                                     Restores 5 HP.
# 54    Reconcile     1        Restores 7 HP each to target and this unit.
# 55       Martyr     1  Restores HP=7+ this unit's suffered damage.Uni...
# 57         Sing     1  Enables target to take another action.Cannot b...
# 6    Reposition     1      Moves adjacent ally to opposite side of unit.
# 62        Smite     1          Push adjacent ally 2 spaces farther away.
# 30  Rally Speed     1  Grants Spd+4 to an adjacent ally until the end...
#
#    SP Cost Default Unlock    Hero  IndexCol
# 3      150       4      3  Arthur         3
# 53       -       3      -   Azama        53
# 54     100       3      -   Azama        54
# 55     200       -      4   Azama        55
# 57     150       5      -   Azura        57
# 6      150       4      3   Barst         6
# 62     150       4      3  Bartre        62
# 30     150       4      -   Caeda        30
#                Name Cooldown  \
# 142  Holy Vestments        3
# 143           Aegis        3
# 23         Daylight        4
# 24              Sol        4
# 48      Dragon Gaze        4
# 49    Draconic Aura        3
# 87        Night Sky        4
# 88            Astra        5
#
#                                                 Effect SP Cost Default Unlock  \
# 142  Reduces damage inflicted by attacks from foes ...     100       4      -
# 143  Reduces damage inflicted by attacks from foes ...     200       -      4
# 23                           Heal 30% of damage dealt.     100       2      -
# 24                           Heal 50% of damage dealt.     200       -      4
# 48                                 Grants +30% to Atk.     100       5      -
# 49                                 Grants +30% to Atk.     200       -      5
# 87                        Grants +50% to damage dealt.     100       2      -
# 88                       Grants +150% to damage dealt.     200       -      4
#
#         Hero  IndexCol
# 142     Abel       142
# 143     Abel       143
# 23   Alfonse        23
# 24   Alfonse        24
# 48       Alm        48
# 49       Alm        49
# 87      Anna        87
# 88      Anna        88
#                Name                                             Effect  \
# 595           HP +3                               Grants +3 to max HP.
# 596           HP +4                               Grants +4 to max HP.
# 597           HP +5                               Grants +5 to max HP.
# 598  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...
# 599  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...
# 600  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...
# 126    Death Blow 1  Grants Atk+2 during combat if unit initiates t...
# 127    Death Blow 2  Grants Atk+4 during combat if unit initiates t...
#
#     SP Cost Unlock Type     Hero  IndexCol
# 595      40      -    A     Abel       595
# 596      80      4    A     Abel       596
# 597     160      5    A     Abel       597
# 598      50      -    B     Abel       598
# 599     100      -    B     Abel       599
# 600     200      4    B     Abel       600
# 126      50      1    A  Alfonse       126
# 127     100      2    A  Alfonse       127

# %%
radiance_hero_pool = {'5': [('red', ['Alm', 'Eirika', 'Eldigan', 'Ogma', 'Cain', 'Corrin', 'Karel', 'Chrom', 'Caeda', 'Seliph',
                            'Marth', 'Ryoma', 'Lyn', 'Lucina', 'Roy', 'Tiki', 'Sanaki', 'Tharja', 'Lilina', 'Leo']),
                          ('blue', ['Azura', 'Abel', 'Ephraim', 'Effie', 'Catria', 'Clair', 'Cordelia', 'Hinoka', 
                            'Peri','Lukas', 'Ninian', 'Nowi', 'Olwen', 'Reinhardt', 'Linde']), 
                          ('green', ['Camilla', 'Sheena', 'Hector', 'Hawkeye', 'Minerva', 'Raven', 'Fae', 
                                     'Merric', 'Julia']), 
                          ('colorless', ['Faye', 'Klein', 'Jeorge','Takumi', 'Rebecca', 'Kagero', 'Jaffar', 'Jakob', 'Elise', 'Sakura', 'Priscilla', 'Maria',
                          'Lachesis', 'Lucius'])], 
                      '4': [('red', ['Erika', 'Eliwood', 'Ogma', 'Olivia', 'Cain', 'Hana', 'Corrin','Chrom', 'Caeda',
                           'Seliph', 'Stahl', 'Draug', 'Palla', 'Hinata', 'Fir', 'Marth', 'Laslow',
                          'Selena', 'Roy', 'Lon\'qu', 'Tiki', 'Sophia', 'Henry', 'Lilina', 'Raigh']),('blue', ['Abel',
                          'Gwendolyn', 'Est', 'Effie', 'Oboro', 'Catria', 'Clair', 'Shanna', 'Jagen', 'Sully',
                          'Subaki', 'Cordelia', 'Donnel', 'Peri', 'Florina', 'Lukas', 'Corrin', 'Nowi', 'Odin',
                          'Reinhardt', 'Robin']),('green', ['Camilla', 'Gunter', 'Sheena', 'Cherche', 'Arthur', 'Bartre',
                          'Barst', 'Frederick', 'Beruka', 'Hawkeye', 'Raven', 'Fae', 'Cecilia', 'Nino', 'Merric']),
                          ('colorless', ['Klein', 'Gordin', 'Jeorge', 'Setsuna', 'Niles', 'Rebecca', 'Virion', 'Kagero', 'Gaius',
                          'Saizo', 'Jakob', 'Felicia', 'Matthew', 'Azama', 'Clarine', 'Sakura', 'Serra', 'Priscilla',
                          'Maria', 'Lachesis', 'Lissa', 'Wrys', 'Lucius'])],
                     '3': [('red', ['Eliwood', 'Olivia', 'Hana', 'Stahl', 'Draug', 'Palla', 'Hinata', 'Fir', 'Laslow',
                          'Selena', 'Lon\'qu', 'Tiki', 'Sophia', 'Henry', 'Raigh']), ('blue', ['Gwendolyn', 'Est', 'Oboro',
                          'Shana', 'Jagen', 'Sully', 'Subaki', 'Donnel', 'Florina', 'Corrin', 'Odin', 'Robin']),
                          ('green', ['Gunter', 'Cherche', 'Arthur', 'Bartre', 'Barst', 'Frederick', 'Beruka', 'Cecilia', 'Nino']),
                          ('colorless', ['Gordin', 'Setsuna', 'Niles', 'Virion', 'Gaius', 'Saizo', 'Felicia', 'Matthew', 'Azama',
                          'Clarine', 'Serra', 'Lissa', 'Wrys'])]}
radiance_focus = ['Ike', 'Titania', 'Soren', 'Mist']

rhp = radiance_hero_pool
print(len(rhp['5']))
print(len(rhp['5'][0][1]))
print(rhp['5'][0][0])
#each key is linked to a list of three tuples. The tuples have two elements, the first is the color in a string,
#the second is the heros at that star, in that color. Is this the best way to do this? Can I figure out a better system?

# generate 5 orbs, based on the percents of getting each color? then open each one, rolling percent on star level,
# and matching to the star and color, then pick from the list.
# Out:
# 4
# 20
# red

# %%
grouped = weapons_df.groupby('Hero', axis = 0)
#grouped.groups
#for key, item in grouped:
#    print(grouped.get_group(key)), '\n\n'
print(grouped.get_group('Abel'))
for name, group in grouped:
    print(name)
    print(group)
# Out:
#              Name Might Range                                       Effect  \
# 417    Iron Lance     6     1                                            -
# 418   Steel Lance     8     1                                            -
# 419   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 420  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock  Hero  IndexCol
# 417      50       -      -  Abel       417
# 418     100       -      -  Abel       418
# 419     200       4      -  Abel       419
# 420     300       5      5  Abel       420
# Abel
#              Name Might Range                                       Effect  \
# 417    Iron Lance     6     1                                            -
# 418   Steel Lance     8     1                                            -
# 419   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 420  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock  Hero  IndexCol
# 417      50       -      -  Abel       417
# 418     100       -      -  Abel       418
# 419     200       4      -  Abel       419
# 420     300       5      5  Abel       420
# Alfonse
#             Name Might Range  \
# 89    Iron Sword     6     1
# 90   Steel Sword     8     1
# 91  Silver Sword    11     1
# 92     Fólkvangr    16     1
#
#                                                Effect SP Cost Default Unlock  \
# 89                                                  -      50       2      -
# 90                                                  -     100       -      2
# 91                                                  -     200       -      3
# 92  Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5
#
#        Hero  IndexCol
# 89  Alfonse        89
# 90  Alfonse        90
# 91  Alfonse        91
# 92  Alfonse        92
# Alm
#              Name Might Range  \
# 153    Iron Sword     6     1
# 154   Steel Sword     8     1
# 155  Silver Sword    11     1
# 156      Falchion    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 153                                                  -      50       -      -
# 154                                                  -     100       -      -
# 155                                                  -     200       -      -
# 156  Effective against dragons. At the start of eve...     400       5      -
#
#     Hero  IndexCol
# 153  Alm       153
# 154  Alm       154
# 155  Alm       155
# 156  Alm       156
# Anna
#            Name Might Range                                            Effect  \
# 253    Iron Axe     6     1                                                 -
# 254   Steel Axe     8     1                                                 -
# 255  Silver Axe    11     1                                                 -
# 256      Nóatún    16     1  Unit may move adjacent to any ally when HP ≤ 40%
#
#     SP Cost Default Unlock  Hero  IndexCol
# 253      50       2      -  Anna       253
# 254     100       -      2  Anna       254
# 255     200       -      3  Anna       255
# 256     400       -      5  Anna       256
# Arthur
#             Name Might Range  \
# 33      Iron Axe     6     1
# 34     Steel Axe     8     1
# 35   Emerald Axe     8     1
# 36  Emerald Axe+    12     1
#
#                                                Effect SP Cost Default Unlock  \
# 33                                                  -      50       -      -
# 34                                                  -     100       3      -
# 35  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 36  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#       Hero  IndexCol
# 33  Arthur        33
# 34  Arthur        34
# 35  Arthur        35
# 36  Arthur        36
# Azama
#         Name Might Range                                            Effect  \
# 328  Assault    10     2                                                 -
# 329     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#     SP Cost Default Unlock   Hero  IndexCol
# 328      50       -      3  Azama       328
# 329     150       -      3  Azama       329
# Azura
#                 Name Might Range  \
# 343       Iron Lance     6     1
# 344      Steel Lance     8     1
# 345   Sapphire Lance     8     1
# 346  Sapphire Lance+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 343                                                  -      50       -      -
# 344                                                  -     100       -      -
# 345  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 346  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
#
#       Hero  IndexCol
# 343  Azura       343
# 344  Azura       344
# 345  Azura       345
# 346  Azura       346
# Barst
#           Name Might Range                                       Effect  \
# 57    Iron Axe     6     1                                            -
# 58   Steel Axe     8     1                                            -
# 59   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 60  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock   Hero  IndexCol
# 57      50       -      -  Barst        57
# 58     100       3      -  Barst        58
# 59     200       4      3  Barst        59
# 60     300       -      5  Barst        60
# Bartre
#           Name Might Range                             Effect SP Cost Default  \
# 357   Iron Axe     6     1                                  -      50       -
# 358  Steel Axe     8     1                                  -     100       3
# 359     Hammer     8     1  Effective against armored units.      200       4
# 360    Hammer+    12     1  Effective against armored units.      200       -
#
#     Unlock    Hero  IndexCol
# 357      -  Bartre       357
# 358      -  Bartre       358
# 359      3  Bartre       359
# 360      5  Bartre       360
# Beruka
#             Name Might Range                                           Effect  \
# 249     Iron Axe     6     1                                                -
# 250    Steel Axe     8     1                                                -
# 251   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 252  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock    Hero  IndexCol
# 249      50       -      -  Beruka       249
# 250     100       3      -  Beruka       250
# 251     200       4      3  Beruka       251
# 252     300       5      5  Beruka       252
# Bruno
#            Name Might Range  \
# 330  Valaskjálf    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 330  Enables unit at ≤ 50% HP to strike first, even...     400       -      -
#
#       Hero  IndexCol
# 330  Bruno       330
# Caeda
#              Name Might Range                             Effect SP Cost  \
# 173    Iron Sword     6     1                                  -      50
# 174   Steel Sword     8     1                                  -     100
# 175   Armorslayer     8     1  Effective against armored units.      200
# 176  Armorslayer+    12     1  Effective against armored units.      300
#
#     Default Unlock   Hero  IndexCol
# 173       -      -  Caeda       173
# 174       -      -  Caeda       174
# 175       4      -  Caeda       175
# 176       5      5  Caeda       176
# Cain
#              Name Might Range                                       Effect  \
# 219    Iron Sword     6     1                                            -
# 220   Steel Sword     8     1                                            -
# 221   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 222  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock  Hero  IndexCol
# 219      50       -      -  Cain       219
# 220     100       -      -  Cain       220
# 221     200       4      -  Cain       221
# 222     300       5      5  Cain       222
# Camilla
#            Name Might Range                                       Effect  \
# 243    Iron Axe     6     1                                            -
# 244   Steel Axe     8     1                                            -
# 245   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 246  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock     Hero  IndexCol
# 243      50       -      -  Camilla       243
# 244     100       -      -  Camilla       244
# 245     200       4      -  Camilla       245
# 246     300       5      5  Camilla       246
# Camilla_(Spring_Festival)
#           Name Might Range                                             Effect  \
# 53        Wind     4     2                                                  -
# 54      Elwind     6     2                                                  -
# 55   Green Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 56  Green Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#    SP Cost Default Unlock                       Hero  IndexCol
# 53      50       -      -  Camilla_(Spring_Festival)        53
# 54     100       -      -  Camilla_(Spring_Festival)        54
# 55     200       -      -  Camilla_(Spring_Festival)        55
# 56     300       5      -  Camilla_(Spring_Festival)        56
# Camus
#          Name Might Range                                             Effect  \
# 295  Gradivus    16     1  Enables counterattack regardless of distance i...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 295     400       -      -  Camus       295
# Catria
#              Name Might Range  \
# 25     Iron Lance     6     1
# 26    Steel Lance     8     1
# 27   Killer Lance     7     1
# 28  Killer Lance+    11     1
#
#                                              Effect SP Cost Default Unlock  \
# 25                                                -      50       -      -
# 26                                                -     100       3      -
# 27  Accelerates Special trigger (cooldown count-1).     200       4      3
# 28  Accelerates Special trigger (cooldown count-1).     300       5      5
#
#       Hero  IndexCol
# 25  Catria        25
# 26  Catria        26
# 27  Catria        27
# 28  Catria        28
# Cecilia
#             Name Might Range                                       Effect  \
# 316         Wind     4     2                                            -
# 317       Elwind     6     2                                            -
# 318   Gronnraven     7     2  Grants weapon advantage vs. colorless foes.
# 319  Gronnraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#     SP Cost Default Unlock     Hero  IndexCol
# 316      50       1      -  Cecilia       316
# 317     100       3      2  Cecilia       317
# 318     200       4      3  Cecilia       318
# 319     300       -      5  Cecilia       319
# Cherche
#           Name Might Range                             Effect SP Cost Default  \
# 239   Iron Axe     6     1                                  -      50       -
# 240  Steel Axe     8     1                                  -     100       3
# 241     Hammer     8     1  Effective against armored units.      200       4
# 242    Hammer+    12     1  Effective against armored units.      200       5
#
#     Unlock     Hero  IndexCol
# 239      -  Cherche       239
# 240      -  Cherche       240
# 241      3  Cherche       241
# 242      5  Cherche       242
# Chrom
#              Name Might Range  \
# 181    Iron Sword     6     1
# 182   Steel Sword     8     1
# 183  Silver Sword    11     1
# 184      Falchion    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 181                                                  -      50       -      -
# 182                                                  -     100       -      -
# 183                                                  -     200       4      -
# 184  Effective against dragons. At the start of eve...     400       5      5
#
#       Hero  IndexCol
# 181  Chrom       181
# 182  Chrom       182
# 183  Chrom       183
# 184  Chrom       184
# Chrom_(Spring_Festival)
#             Name Might Range  \
# 437     Iron Axe     6     1
# 438    Steel Axe     8     1
# 439   Carrot Axe     9     1
# 440  Carrot Axe+    13     1
#
#                                                 Effect SP Cost Default Unlock  \
# 437                                                  -      50       -      -
# 438                                                  -     100       -      -
# 439  If unit initiates attack, unit recovers 4 HP a...     200       -      -
# 440  If unit initiates attack, unit recovers 4 HP a...     300       5      -
#
#                         Hero  IndexCol
# 437  Chrom_(Spring_Festival)       437
# 438  Chrom_(Spring_Festival)       438
# 439  Chrom_(Spring_Festival)       439
# 440  Chrom_(Spring_Festival)       440
# Clair
#               Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 127     Iron Lance     6     1      -      50       -      -  Clair       127
# 128    Steel Lance     8     1      -     100       -      -  Clair       128
# 129   Silver Lance    11     1      -     200       4      -  Clair       129
# 130  Silver Lance+    15     1      -     300       5      -  Clair       130
# Clarine
#         Name Might Range                                             Effect  \
# 407  Assault    10     2                                                  -
# 408     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#     SP Cost Default Unlock     Hero  IndexCol
# 407      50       -      -  Clarine       407
# 408     150       -      3  Clarine       408
# Cordelia
#              Name Might Range                                       Effect  \
# 447    Iron Lance     6     1                                            -
# 448   Steel Lance     8     1                                            -
# 449   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 450  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock      Hero  IndexCol
# 447      50       -      -  Cordelia       447
# 448     100       -      -  Cordelia       448
# 449     200       4      -  Cordelia       449
# 450     300       5      5  Cordelia       450
# Corrin_(F)
#              Name Might Range  \
# 399   Fire Breath     6     1
# 400  Fire Breath+     8     1
# 401   Dark Breath     9     1
# 402  Dark Breath+    13     1
#
#                                                 Effect SP Cost Default Unlock  \
# 399                                                  -      50       -      -
# 400                                                  -     100       3      -
# 401  After this unit attacks, foes within 2 spaces ...     200       4      3
# 402  After this unit attacks, foes within 2 spaces ...     300       -      5
#
#            Hero  IndexCol
# 399  Corrin_(F)       399
# 400  Corrin_(F)       400
# 401  Corrin_(F)       401
# 402  Corrin_(F)       402
# Corrin_(M)
#              Name Might Range  \
# 189    Iron Sword     6     1
# 190   Steel Sword     8     1
# 191  Silver Sword    11     1
# 192          Yato    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 189                                                  -      50       -      -
# 190                                                  -     100       -      -
# 191                                                  -     200       4      -
# 192  Grants Spd+4 during combat if unit initiates a...     400       5      5
#
#            Hero  IndexCol
# 189  Corrin_(M)       189
# 190  Corrin_(M)       190
# 191  Corrin_(M)       191
# 192  Corrin_(M)       192
# Donnel
#             Name Might Range                                       Effect  \
# 41    Iron Lance     6     1                                            -
# 42   Steel Lance     8     1                                            -
# 43   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 44  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock    Hero  IndexCol
# 41      50       1      -  Donnel        41
# 42     100       3      2  Donnel        42
# 43     200       4      3  Donnel        43
# 44     300       -      5  Donnel        44
# Draug
#             Name Might Range                                       Effect  \
# 93    Iron Sword     6     1                                            -
# 94   Steel Sword     8     1                                            -
# 95   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 96  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock   Hero  IndexCol
# 93      50       2      -  Draug        93
# 94     100       -      2  Draug        94
# 95     200       4      3  Draug        95
# 96     300       5      5  Draug        96
# Effie
#               Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 347     Iron Lance     6     1      -      50       -      -  Effie       347
# 348    Steel Lance     8     1      -     100       -      -  Effie       348
# 349   Silver Lance    11     1      -     200       4      -  Effie       349
# 350  Silver Lance+    15     1      -     300       5      5  Effie       350
# Eirika
#              Name Might Range  \
# 391    Iron Sword     6     1
# 392   Steel Sword     8     1
# 393  Silver Sword    11     1
# 394     Sieglinde    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 391                                                  -      50       -      -
# 392                                                  -     100       -      -
# 393                                                  -     200       4      -
# 394  Grants adjacent allies Atk+3 through their nex...     400       5      5
#
#        Hero  IndexCol
# 391  Eirika       391
# 392  Eirika       392
# 393  Eirika       393
# 394  Eirika       394
# Eldigan
#              Name Might Range  \
# 169    Iron Sword     6     1
# 170   Steel Sword     8     1
# 171  Killing Edge     7     1
# 172   Mystletainn    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 169                                                -      50       -      -
# 170                                                -     100       -      -
# 171  Accelerates Special trigger (cooldown count-1).     200       -      -
# 172  Accelerates Special trigger (cooldown count-1).     400       5      -
#
#         Hero  IndexCol
# 169  Eldigan       169
# 170  Eldigan       170
# 171  Eldigan       171
# 172  Eldigan       172
# Elise
#         Name Might Range                                             Effect  \
# 125  Assault    10     2                                                  -
# 126  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 125      50       -      -  Elise       125
# 126     150       -      -  Elise       126
# Eliwood
#              Name Might Range  \
# 97     Iron Sword     6     1
# 98    Steel Sword     8     1
# 99   Silver Sword    11     1
# 100      Durandal    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 97                                                   -      50       -      -
# 98                                                   -     100       3      -
# 99                                                   -     200       4      3
# 100  Grants Atk+4 during combat if unit initiates a...     400       5      5
#
#         Hero  IndexCol
# 97   Eliwood        97
# 98   Eliwood        98
# 99   Eliwood        99
# 100  Eliwood       100
# Ephraim
#            Name Might Range  \
# 45   Iron Lance     6     1
# 46  Steel Lance     8     1
# 47  Heavy Spear     8     1
# 48     Siegmund    16     1
#
#                                                Effect SP Cost Default Unlock  \
# 45                                                  -      50       -      -
# 46                                                  -     100       -      -
# 47                  Effective against armored units.      200       -      -
# 48  Grants adjacent allies Atk+3 through their nex...     400       5      -
#
#        Hero  IndexCol
# 45  Ephraim        45
# 46  Ephraim        46
# 47  Ephraim        47
# 48  Ephraim        48
# Est
#             Name Might Range                             Effect SP Cost  \
# 17    Iron Lance     6     1                                  -      50
# 18   Steel Lance     8     1                                  -     100
# 19   Heavy Spear     8     1  Effective against armored units.      200
# 20  Heavy Spear+    12     1  Effective against armored units.      300
#
#    Default Unlock Hero  IndexCol
# 17       -      -  Est        17
# 18       3      -  Est        18
# 19       4      3  Est        19
# 20       -      5  Est        20
# Fae
#              Name Might Range  \
# 65    Fire Breath     6     1
# 66   Fire Breath+     8     1
# 67   Light Breath     9     1
# 68  Light Breath+    13     1
#
#                                                Effect SP Cost Default Unlock  \
# 65                                                  -      50       -      -
# 66                                                  -     100       -      -
# 67  Grants adjacent allies Def/Res+4 through their...     200       4      -
# 68  Grants adjacent allies Def/Res+4 through their...     300       5      5
#
#    Hero  IndexCol
# 65  Fae        65
# 66  Fae        66
# 67  Fae        67
# 68  Fae        68
# Faye
#                Name Might Range  \
# 101        Iron Bow     4     2
# 102       Steel Bow     6     2
# 103   Firesweep Bow     7     2
# 104  Firesweep Bow+    11     2
#
#                                                 Effect SP Cost Default Unlock  \
# 101                   Effective against flying units.       50       -      -
# 102                   Effective against flying units.      100       -      -
# 103  Effective against flying units. Unit and enemi...     200       -      -
# 104  Effective against flying units. Unit and enemi...     300       5      -
#
#      Hero  IndexCol
# 101  Faye       101
# 102  Faye       102
# 103  Faye       103
# 104  Faye       104
# Felicia
#                Name Might Range  \
# 387     Iron Dagger     3     2
# 388    Steel Dagger     5     2
# 389   Silver Dagger     7     2
# 390  Silver Dagger+    10     2
#
#                                                 Effect SP Cost Default Unlock  \
# 387  After combat, inflicts Def/Res-3 on foe throug...      50       1      -
# 388  After combat, inflicts Def/Res-3 on foe throug...     100       3      2
# 389  After combat, inflicts Def/Res-5 on foe throug...     200       4      3
# 390  After combat, inflicts Def/Res-7 on foe throug...     300       5      5
#
#         Hero  IndexCol
# 387  Felicia       387
# 388  Felicia       388
# 389  Felicia       389
# 390  Felicia       390
# Fir
#               Name Might Range  \
# 413     Iron Sword     6     1
# 414    Steel Sword     8     1
# 415   Killing Edge     7     1
# 416  Killing Edge+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 413                                                -      50       -      -
# 414                                                -     100       3      -
# 415  Accelerates Special trigger (cooldown count-1).     200       4      3
# 416  Accelerates Special trigger (cooldown count-1).     300       5      5
#
#     Hero  IndexCol
# 413  Fir       413
# 414  Fir       414
# 415  Fir       415
# 416  Fir       416
# Florina
#              Name Might Range                             Effect SP Cost  \
# 296    Iron Lance     6     1                                  -      50
# 297   Steel Lance     8     1                                  -     100
# 298   Heavy Spear     8     1  Effective against armored units.      200
# 299  Heavy Spear+    12     1  Effective against armored units.      300
#
#     Default Unlock     Hero  IndexCol
# 296       -      -  Florina       296
# 297       3      -  Florina       297
# 298       4      3  Florina       298
# 299       -      5  Florina       299
# Frederick
#           Name Might Range                             Effect SP Cost Default  \
# 379   Iron Axe     6     1                                  -      50       -
# 380  Steel Axe     8     1                                  -     100       3
# 381     Hammer     8     1  Effective against armored units.      200       4
# 382    Hammer+    12     1  Effective against armored units.      200       5
#
#     Unlock       Hero  IndexCol
# 379      -  Frederick       379
# 380      -  Frederick       380
# 381      3  Frederick       381
# 382      5  Frederick       382
# Gaius
#              Name Might Range  \
# 9     Iron Dagger     3     2
# 10   Steel Dagger     5     2
# 11   Rogue Dagger     4     2
# 12  Rogue Dagger+     7     2
#
#                                                Effect SP Cost Default Unlock  \
# 9   After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 10  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 11  After combat, inflicts Def/Res-3 on foe throug...     200       4      3
# 12  After combat, inflicts Def/Res-5 on foe throug...     300       -      5
#
#      Hero  IndexCol
# 9   Gaius         9
# 10  Gaius        10
# 11  Gaius        11
# 12  Gaius        12
# Gordin
#            Name Might Range  \
# 291    Iron Bow     4     2
# 292   Steel Bow     6     2
# 293   Brave Bow     4     2
# 294  Brave Bow+     7     2
#
#                                                 Effect SP Cost Default Unlock  \
# 291                   Effective against flying units.       50       -      -
# 292                   Effective against flying units.      100       3      -
# 293  Spd-5. Effective against flying units. Attacks...     200       4      3
# 294  Spd-5. Effective against flying units. Attacks...     300       5      5
#
#        Hero  IndexCol
# 291  Gordin       291
# 292  Gordin       292
# 293  Gordin       293
# 294  Gordin       294
# Gunter
#             Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 304     Iron Axe     6     1      -      50       1      -  Gunter       304
# 305    Steel Axe     8     1      -     100       3      2  Gunter       305
# 306   Silver Axe    11     1      -     200       4      3  Gunter       306
# 307  Silver Axe+    15     1      -     300       -      5  Gunter       307
# Gwendolyn
#               Name Might Range  \
# 261     Iron Lance     6     1
# 262    Steel Lance     8     1
# 263   Killer Lance     7     1
# 264  Killer Lance+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 261                                                -      50       -      -
# 262                                                -     100       3      -
# 263  Accelerates Special trigger (cooldown count-1).     200       4      3
# 264  Accelerates Special trigger (cooldown count-1).     300       -      5
#
#           Hero  IndexCol
# 261  Gwendolyn       261
# 262  Gwendolyn       262
# 263  Gwendolyn       263
# 264  Gwendolyn       264
# Hana
#              Name Might Range                             Effect SP Cost  \
# 455    Iron Sword     6     1                                  -      50
# 456   Steel Sword     8     1                                  -     100
# 457   Armorslayer     8     1  Effective against armored units.      200
# 458  Armorslayer+    12     1  Effective against armored units.      300
#
#     Default Unlock  Hero  IndexCol
# 455       1      -  Hana       455
# 456       3      2  Hana       456
# 457       4      3  Hana       457
# 458       5      5  Hana       458
# Hawkeye
#             Name Might Range                                           Effect  \
# 475     Iron Axe     6     1                                                -
# 476    Steel Axe     8     1                                                -
# 477   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 478  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock     Hero  IndexCol
# 475      50       -      -  Hawkeye       475
# 476     100       -      -  Hawkeye       476
# 477     200       4      3  Hawkeye       477
# 478     300       5      5  Hawkeye       478
# Hector
#            Name Might Range  \
# 409    Iron Axe     6     1
# 410   Steel Axe     8     1
# 411  Silver Axe    11     1
# 412      Armads    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 409                                                  -      50       -      -
# 410                                                  -     100       -      -
# 411                                                  -     200       -      -
# 412  Unit makes a guaranteed follow-up attack when ...     400       5      -
#
#        Hero  IndexCol
# 409  Hector       409
# 410  Hector       410
# 411  Hector       411
# 412  Hector       412
# Henry
#             Name Might Range                                       Effect  \
# 223         Flux     4     2                                            -
# 224         Ruin     6     2                                            -
# 225   Rauðrraven     7     2  Grants weapon advantage vs. colorless foes.
# 226  Rauðrraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#     SP Cost Default Unlock   Hero  IndexCol
# 223      50       -      -  Henry       223
# 224     100       3      -  Henry       224
# 225     200       4      3  Henry       225
# 226     300       -      5  Henry       226
# Hinata
#             Name Might Range  \
# 277   Iron Sword     6     1
# 278  Steel Sword     8     1
# 279   Ruby Sword     8     1
# 280  Ruby Sword+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 277                                                  -      50       1      -
# 278                                                  -     100       3      2
# 279  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 280  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#        Hero  IndexCol
# 277  Hinata       277
# 278  Hinata       278
# 279  Hinata       279
# 280  Hinata       280
# Hinoka
#              Name Might Range                                       Effect  \
# 403    Iron Lance     6     1                                            -
# 404   Steel Lance     8     1                                            -
# 405   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 406  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock    Hero  IndexCol
# 403      50       -      -  Hinoka       403
# 404     100       -      -  Hinoka       404
# 405     200       -      -  Hinoka       405
# 406     300       5      -  Hinoka       406
# Ike
#              Name Might Range  \
# 339    Iron Sword     6     1
# 340   Steel Sword     8     1
# 341  Silver Sword    11     1
# 342       Ragnell    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 339                                                  -      50       -      -
# 340                                                  -     100       -      -
# 341                                                  -     200       -      -
# 342  Enables counterattack regardless of distance i...     400       5      -
#
#     Hero  IndexCol
# 339  Ike       339
# 340  Ike       340
# 341  Ike       341
# 342  Ike       342
# Jaffar
#               Name Might Range  \
# 37     Iron Dagger     3     2
# 38    Steel Dagger     5     2
# 39   Silver Dagger     7     2
# 40  Deathly Dagger    11     2
#
#                                                Effect SP Cost Default Unlock  \
# 37  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 38  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 39  After combat, inflicts Def/Res-5 on foe throug...     200       -      -
# 40  After combat, inflicts Def/Res-7 on foe throug...     400       5      -
#
#       Hero  IndexCol
# 37  Jaffar        37
# 38  Jaffar        38
# 39  Jaffar        39
# 40  Jaffar        40
# Jagen
#               Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 365     Iron Lance     6     1      -      50       -      -  Jagen       365
# 366    Steel Lance     8     1      -     100       3      -  Jagen       366
# 367   Silver Lance    11     1      -     200       4      3  Jagen       367
# 368  Silver Lance+    15     1      -     300       -      5  Jagen       368
# Jakob
#              Name Might Range  \
# 5     Iron Dagger     3     2
# 6    Steel Dagger     5     2
# 7   Silver Dagger     7     2
# 8  Silver Dagger+    10     2
#
#                                               Effect SP Cost Default Unlock  \
# 5  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 6  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 7  After combat, inflicts Def/Res-5 on foe throug...     200       4      -
# 8  After combat, inflicts Def/Res-7 on foe throug...     300       5      5
#
#     Hero  IndexCol
# 5  Jakob         5
# 6  Jakob         6
# 7  Jakob         7
# 8  Jakob         8
# Jeorge
#            Name Might Range  \
# 433    Iron Bow     4     2
# 434   Steel Bow     6     2
# 435  Silver Bow     9     2
# 436     Parthia    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 433                   Effective against flying units.       50       -      -
# 434                   Effective against flying units.      100       -      -
# 435                   Effective against flying units.      200       4      -
# 436  Effective against flying units. Grants Res+4 d...     400       5      5
#
#        Hero  IndexCol
# 433  Jeorge       433
# 434  Jeorge       434
# 435  Jeorge       435
# 436  Jeorge       436
# Julia
#            Name Might Range  \
# 207        Wind     4     2
# 208      Elwind     6     2
# 209  Rexcalibur     9     2
# 210        Naga    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 207                                                  -      50       -      -
# 208                                                  -     100       -      -
# 209                                                  -     200       -      -
# 210  Effective against dragons. Grants Def/Res+2 wh...     400       5      -
#
#       Hero  IndexCol
# 207  Julia       207
# 208  Julia       208
# 209  Julia       209
# 210  Julia       210
# Kagero
#                Name Might Range  \
# 215     Iron Dagger     3     2
# 216    Steel Dagger     5     2
# 217   Poison Dagger     2     2
# 218  Poison Dagger+     5     2
#
#                                                 Effect SP Cost Default Unlock  \
# 215  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 216  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 217  Effective against infantry units. Infantry foe...     200       4      -
# 218  Effective against infantry units. Infantry foe...     300       5      5
#
#        Hero  IndexCol
# 215  Kagero       215
# 216  Kagero       216
# 217  Kagero       217
# 218  Kagero       218
# Karel
#             Name Might Range                                       Effect  \
# 285   Iron Sword     6     1                                            -
# 286  Steel Sword     8     1                                            -
# 287       Wo Dao     9     1  Grants +10 to damage when Special triggers.
# 288      Wo Dao+    13     1  Grants +10 to damage when Special triggers.
#
#     SP Cost Default Unlock   Hero  IndexCol
# 285      50       -      -  Karel       285
# 286     100       -      -  Karel       286
# 287     200       -      -  Karel       287
# 288     300       5      -  Karel       288
# Klein
#           Name Might Range                                             Effect  \
# 29    Iron Bow     4     2                   Effective against flying units.
# 30   Steel Bow     6     2                   Effective against flying units.
# 31   Brave Bow     4     2  Spd-5. Effective against flying units. Attacks...
# 32  Brave Bow+     7     2  Spd-5. Effective against flying units. Attacks...
#
#    SP Cost Default Unlock   Hero  IndexCol
# 29      50       -      -  Klein        29
# 30     100       -      -  Klein        30
# 31     200       4      -  Klein        31
# 32     300       5      5  Klein        32
# Lachesis
#         Name Might Range                            Effect SP Cost Default  \
# 109  Assault    10     2                                 -      50       -
# 110   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#     Unlock      Hero  IndexCol
# 109      -  Lachesis       109
# 110      4  Lachesis       110
# Laslow
#               Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 177     Iron Sword     6     1      -      50       -      -  Laslow       177
# 178    Steel Sword     8     1      -     100       3      -  Laslow       178
# 179   Silver Sword    11     1      -     200       4      3  Laslow       179
# 180  Silver Sword+    15     1      -     300       -      5  Laslow       180
# Leo
#           Name Might Range                                             Effect  \
# 361       Flux     4     2                                                  -
# 362       Ruin     6     2                                                  -
# 363     Fenrir     9     2                                                  -
# 364  Brynhildr    14     2  If unit initiates attack, restricts foe's next...
#
#     SP Cost Default Unlock Hero  IndexCol
# 361      50       -      -  Leo       361
# 362     100       -      -  Leo       362
# 363     200       -      -  Leo       363
# 364     400       5      -  Leo       364
# Lilina
#            Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 471        Fire     4     2      -      50       -      -  Lilina       471
# 472      Elfire     6     2      -     100       -      -  Lilina       472
# 473   Bolganone     9     2      -     200       4      -  Lilina       473
# 474  Bolganone+    13     2      -     300       5      5  Lilina       474
# Linde
#           Name Might Range                                             Effect  \
# 421    Thunder     4     2                                                  -
# 422  Elthunder     6     2                                                  -
# 423     Thoron     9     2                                                  -
# 424       Aura    14     2  Restores 5 HP to adjacent allies after any com...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 421      50       -      -  Linde       421
# 422     100       -      -  Linde       422
# 423     200       -      -  Linde       423
# 424     400       5      -  Linde       424
# Lissa
#         Name Might Range                                             Effect  \
# 147  Assault    10     2                                                  -
# 148  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 147      50       -      1  Lissa       147
# 148     150       -      3  Lissa       148
# Lon'qu
#              Name Might Range  \
# 49     Iron Sword     6     1
# 50    Steel Sword     8     1
# 51   Killing Edge     7     1
# 52  Killing Edge+    11     1
#
#                                              Effect SP Cost Default Unlock  \
# 49                                                -      50       -      -
# 50                                                -     100       3      -
# 51  Accelerates Special trigger (cooldown count-1).     200       4      3
# 52  Accelerates Special trigger (cooldown count-1).     300       -      5
#
#       Hero  IndexCol
# 49  Lon'qu        49
# 50  Lon'qu        50
# 51  Lon'qu        51
# 52  Lon'qu        52
# Lucina
#             Name Might Range  \
# 13    Iron Sword     6     1
# 14   Steel Sword     8     1
# 15  Silver Sword    11     1
# 16      Falchion    16     1
#
#                                                Effect SP Cost Default Unlock  \
# 13                                                  -      50       -      -
# 14                                                  -     100       -      -
# 15                                                  -     200       -      -
# 16  Effective against dragons. At the start of eve...     400       5      -
#
#       Hero  IndexCol
# 13  Lucina        13
# 14  Lucina        14
# 15  Lucina        15
# 16  Lucina        16
# Lucina_(Spring_Festival)
#           Name Might Range                                             Effect  \
# 320    Thunder     4     2                                                  -
# 321  Elthunder     6     2                                                  -
# 322   Blue Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 323  Blue Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#     SP Cost Default Unlock                      Hero  IndexCol
# 320      50       -      -  Lucina_(Spring_Festival)       320
# 321     100       -      -  Lucina_(Spring_Festival)       321
# 322     200       -      -  Lucina_(Spring_Festival)       322
# 323     300       5      -  Lucina_(Spring_Festival)       323
# Lucius
#         Name Might Range                                            Effect  \
# 445  Assault    10     2                                                 -
# 446     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#     SP Cost Default Unlock    Hero  IndexCol
# 445      50       -      4  Lucius       445
# 446     150       -      4  Lucius       446
# Lukas
#               Name Might Range  \
# 193     Iron Lance     6     1
# 194    Steel Lance     8     1
# 195   Killer Lance     7     1
# 196  Killer Lance+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 193                                                -      50       -      -
# 194                                                -     100       -      -
# 195  Accelerates Special trigger (cooldown count-1).     200       4      -
# 196  Accelerates Special trigger (cooldown count-1).     300       5      -
#
#       Hero  IndexCol
# 193  Lukas       193
# 194  Lukas       194
# 195  Lukas       195
# 196  Lukas       196
# Lyn
#              Name Might Range  \
# 149    Iron Sword     6     1
# 150   Steel Sword     8     1
# 151  Silver Sword    11     1
# 152     Sol Katti    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 149                                                  -      50       -      -
# 150                                                  -     100       -      -
# 151                                                  -     200       -      -
# 152  If wielder initiates attack at HP ≤ 50%, any f...     400       5      -
#
#     Hero  IndexCol
# 149  Lyn       149
# 150  Lyn       150
# 151  Lyn       151
# 152  Lyn       152
# Maria
#         Name Might Range                                             Effect  \
# 373  Assault    10     2                                                  -
# 374    Panic     7     2  After combat, bonuses on targeted foe become p...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 373      50       -      4  Maria       373
# 374     150       -      4  Maria       374
# Marth
#              Name Might Range  \
# 131    Iron Sword     6     1
# 132   Steel Sword     8     1
# 133  Silver Sword    11     1
# 134      Falchion    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 131                                                  -      50       -      -
# 132                                                  -     100       -      -
# 133                                                  -     200       4      -
# 134  Effective against dragons. At the start of eve...     400       5      5
#
#       Hero  IndexCol
# 131  Marth       131
# 132  Marth       132
# 133  Marth       133
# 134  Marth       134
# Matthew
#               Name Might Range  \
# 369    Iron Dagger     3     2
# 370   Steel Dagger     5     2
# 371   Rogue Dagger     4     2
# 372  Rogue Dagger+     7     2
#
#                                                 Effect SP Cost Default Unlock  \
# 369  After combat, inflicts Def/Res-3 on foe throug...      50       2      -
# 370  After combat, inflicts Def/Res-3 on foe throug...     100       3      2
# 371  After combat, inflicts Def/Res-3 on foe throug...     200       4      3
# 372  After combat, inflicts Def/Res-5 on foe throug...     300       -      5
#
#         Hero  IndexCol
# 369  Matthew       369
# 370  Matthew       370
# 371  Matthew       371
# 372  Matthew       372
# Merric
#            Name Might Range                            Effect SP Cost Default  \
# 425        Wind     4     2                                 -      50       -
# 426      Elwind     6     2                                 -     100       -
# 427  Rexcalibur     9     2                                 -     200       4
# 428   Excalibur    14     2  Effective against flying units.      400       5
#
#     Unlock    Hero  IndexCol
# 425      -  Merric       425
# 426      -  Merric       426
# 427      -  Merric       427
# 428      5  Merric       428
# Michalis
#            Name Might Range                                           Effect  \
# 463    Iron Axe     6     1                                                -
# 464   Steel Axe     8     1                                                -
# 465  Silver Axe    11     1                                                -
# 466  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock      Hero  IndexCol
# 463      50       -      -  Michalis       463
# 464     100       3      -  Michalis       464
# 465     200       4      3  Michalis       465
# 466     400       -      5  Michalis       466
# Minerva
#            Name Might Range                                           Effect  \
# 115    Iron Axe     6     1                                                -
# 116   Steel Axe     8     1                                                -
# 117  Silver Axe    11     1                                                -
# 118  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock     Hero  IndexCol
# 115      50       -      -  Minerva       115
# 116     100       -      -  Minerva       116
# 117     200       -      -  Minerva       117
# 118     400       5      -  Minerva       118
# Mist
# ...
# 139  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 140  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 141  After combat, inflicts Def/Res-4 on foes withi...     200       4      3
# 142  After combat, inflicts Def/Res-6 on foes withi...     300       -      5
#
#       Hero  IndexCol
# 139  Saizo       139
# 140  Saizo       140
# 141  Saizo       141
# 142  Saizo       142
# Sakura
#         Name Might Range                                             Effect  \
# 201  Assault    10     2                                                  -
# 202     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#     SP Cost Default Unlock    Hero  IndexCol
# 201      50       -      -  Sakura       201
# 202     150       -      4  Sakura       202
# Sanaki
#           Name Might Range                                             Effect  \
# 165       Fire     4     2                                                  -
# 166     Elfire     6     2                                                  -
# 167  Bolganone     9     2                                                  -
# 168  Cymbeline    14     2  Grants adjacent allies Atk+4 through their nex...
#
#     SP Cost Default Unlock    Hero  IndexCol
# 165      50       -      -  Sanaki       165
# 166     100       -      -  Sanaki       166
# 167     200       -      -  Sanaki       167
# 168     400       5      -  Sanaki       168
# Selena
#              Name Might Range                             Effect SP Cost  \
# 331    Iron Sword     6     1                                  -      50
# 332   Steel Sword     8     1                                  -     100
# 333   Armorslayer     8     1  Effective against armored units.      200
# 334  Armorslayer+    12     1  Effective against armored units.      300
#
#     Default Unlock    Hero  IndexCol
# 331       -      -  Selena       331
# 332       3      -  Selena       332
# 333       4      3  Selena       333
# 334       5      5  Selena       334
# Seliph
#             Name Might Range                                      Effect  \
# 61    Iron Sword     6     1                                           -
# 62   Steel Sword     8     1                                           -
# 63  Silver Sword    11     1                                           -
# 64       Tyrfing    16     1  Grants Def+4 in battle if unit's HP ≤ 50%.
#
#    SP Cost Default Unlock    Hero  IndexCol
# 61      50       -      -  Seliph        61
# 62     100       -      -  Seliph        62
# 63     200       4      -  Seliph        63
# 64     400       5      5  Seliph        64
# Serra
#         Name Might Range                            Effect SP Cost Default  \
# 289  Assault    10     2                                 -      50       -
# 290   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#     Unlock   Hero  IndexCol
# 289      -  Serra       289
# 290      3  Serra       290
# Setsuna
#                Name Might Range  \
# 69         Iron Bow     4     2
# 70        Steel Bow     6     2
# 71   Assassin's Bow     7     2
# 72  Assassin's Bow+    11     2
#
#                                                Effect SP Cost Default Unlock  \
# 69                   Effective against flying units.       50       -      -
# 70                   Effective against flying units.      100       3      -
# 71  Effective against flying units. If target has ...     200       4      3
# 72  Effective against flying units. If target has ...     300       5      5
#
#        Hero  IndexCol
# 69  Setsuna        69
# 70  Setsuna        70
# 71  Setsuna        71
# 72  Setsuna        72
# Shanna
#               Name Might Range  \
# 121     Iron Lance     6     1
# 122    Steel Lance     8     1
# 123   Killer Lance     7     1
# 124  Killer Lance+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 121                                                -      50       -      -
# 122                                                -     100       3      -
# 123  Accelerates Special trigger (cooldown count-1).     200       4      3
# 124  Accelerates Special trigger (cooldown count-1).     300       -      5
#
#        Hero  IndexCol
# 121  Shanna       121
# 122  Shanna       122
# 123  Shanna       123
# 124  Shanna       124
# Sharena
#              Name Might Range  \
# 111    Iron Lance     6     1
# 112   Steel Lance     8     1
# 113  Silver Lance    11     1
# 114      Fensalir    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 111                                                  -      50       2      -
# 112                                                  -     100       -      2
# 113                                                  -     200       -      3
# 114  Inflicts Atk-4 on foes within 2 spaces through...     400       -      5
#
#         Hero  IndexCol
# 111  Sharena       111
# 112  Sharena       112
# 113  Sharena       113
# 114  Sharena       114
# Sheena
#             Name Might Range                                           Effect  \
# 324     Iron Axe     6     1                                                -
# 325    Steel Axe     8     1                                                -
# 326   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 327  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock    Hero  IndexCol
# 324      50       -      -  Sheena       324
# 325     100       -      -  Sheena       325
# 326     200       4      -  Sheena       326
# 327     300       5      5  Sheena       327
# Sophia
#         Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 300     Flux     4     2      -      50       1      -  Sophia       300
# 301     Ruin     6     2      -     100       3      2  Sophia       301
# 302   Fenrir     9     2      -     200       4      3  Sophia       302
# 303  Fenrir+    13     2      -     300       -      5  Sophia       303
# Soren
#             Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 335         Wind     4     2      -      50       -      -  Soren       335
# 336       Elwind     6     2      -     100       -      -  Soren       336
# 337   Rexcalibur     9     2      -     200       -      -  Soren       337
# 338  Rexcalibur+    13     2      -     300       5      -  Soren       338
# Stahl
#             Name Might Range  \
# 203   Iron Sword     6     1
# 204  Steel Sword     8     1
# 205   Ruby Sword     8     1
# 206  Ruby Sword+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 203                                                  -      50       1      -
# 204                                                  -     100       3      2
# 205  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 206  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#       Hero  IndexCol
# 203  Stahl       203
# 204  Stahl       204
# 205  Stahl       205
# 206  Stahl       206
# Subaki
#                 Name Might Range  \
# 273       Iron Lance     6     1
# 274      Steel Lance     8     1
# 275   Sapphire Lance     8     1
# 276  Sapphire Lance+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 273                                                  -      50       1      -
# 274                                                  -     100       3      2
# 275  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 276  Gives Atk+20% if weapon-triangle advantage, At...     300       5      5
#
#        Hero  IndexCol
# 273  Subaki       273
# 274  Subaki       274
# 275  Subaki       275
# 276  Subaki       276
# Sully
#                 Name Might Range  \
# 211       Iron Lance     6     1
# 212      Steel Lance     8     1
# 213   Sapphire Lance     8     1
# 214  Sapphire Lance+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 211                                                  -      50       1      -
# 212                                                  -     100       3      2
# 213  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 214  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#       Hero  IndexCol
# 211  Sully       211
# 212  Sully       212
# 213  Sully       213
# 214  Sully       214
# Takumi
#            Name Might Range  \
# 257    Iron Bow     4     2
# 258   Steel Bow     6     2
# 259  Silver Bow     9     2
# 260  Fujin Yumi    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 257                   Effective against flying units.       50       -      -
# 258                   Effective against flying units.      100       -      -
# 259                   Effective against flying units.      200       -      -
# 260  Effective against flying units. Unit can pass ...     400       5      -
#
#        Hero  IndexCol
# 257  Takumi       257
# 258  Takumi       258
# 259  Takumi       259
# 260  Takumi       260
# Tharja
#             Name Might Range  \
# 459         Flux     4     2
# 460         Ruin     6     2
# 461   Rauðrblade     9     2
# 462  Rauðrblade+    13     2
#
#                                                 Effect SP Cost Default Unlock  \
# 459                                                  -      50       -      -
# 460                                                  -     100       -      -
# 461  Slows Special trigger (cooldown count+1).Adds ...     200       4      -
# 462  Slows Special trigger (cooldown count+1).Adds ...     300       5      5
#
#        Hero  IndexCol
# 459  Tharja       459
# 460  Tharja       460
# 461  Tharja       461
# 462  Tharja       462
# Tiki_(Adult)
#                   Name Might Range  \
# 157        Fire Breath     6     1
# 158       Fire Breath+     8     1
# 159   Lightning Breath     7     1
# 160  Lightning Breath+    11     1
#
#                                                 Effect SP Cost Default Unlock  \
# 157                                                  -      50       -      -
# 158                                                  -     100       3      -
# 159  Enables counterattack regardless of attacker's...     200       4      3
# 160  Enables counterattack regardless of attacker's...     300       5      5
#
#              Hero  IndexCol
# 157  Tiki_(Adult)       157
# 158  Tiki_(Adult)       158
# 159  Tiki_(Adult)       159
# 160  Tiki_(Adult)       160
# Tiki_(Young)
#              Name Might Range Effect SP Cost Default Unlock          Hero  \
# 308   Fire Breath     6     1      -      50       -      -  Tiki_(Young)
# 309  Fire Breath+     8     1      -     100       -      -  Tiki_(Young)
# 310   Flametongue    11     1      -     200       -      -  Tiki_(Young)
# 311  Flametongue+    15     1      -     300       5      -  Tiki_(Young)
#
#      IndexCol
# 308       308
# 309       309
# 310       310
# 311       311
# Titania
#              Name Might Range  \
# 395      Iron Axe     6     1
# 396     Steel Axe     8     1
# 397   Emerald Axe     8     1
# 398  Emerald Axe+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 395                                                  -      50       -      -
# 396                                                  -     100       -      -
# 397  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 398  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
#
#         Hero  IndexCol
# 395  Titania       395
# 396  Titania       396
# 397  Titania       397
# 398  Titania       398
# Ursula
#           Name Might Range                            Effect SP Cost Default  \
# 197    Thunder     4     2                                 -      50       -
# 198  Elthunder     6     2                                 -     100       3
# 199   Blárwolf     6     2  Effective against cavalry units.     200       4
# 200  Blárwolf+    10     2  Effective against cavalry units.     300       -
#
#     Unlock    Hero  IndexCol
# 197      -  Ursula       197
# 198      -  Ursula       198
# 199      3  Ursula       199
# 200      5  Ursula       200
# Veronica
#        Name Might Range                                             Effect  \
# 4  Élivágar    14     2  If unit initiates attack, bonuses on foes with...
#
#   SP Cost Default Unlock      Hero  IndexCol
# 4     400       -      -  Veronica         4
# Virion
#             Name Might Range                            Effect SP Cost  \
# 235     Iron Bow     4     2  Effective against flying units.       50
# 236    Steel Bow     6     2  Effective against flying units.      100
# 237   Silver Bow     9     2  Effective against flying units.      200
# 238  Silver Bow+    13     2  Effective against flying units.      300
#
#     Default Unlock    Hero  IndexCol
# 235       1      -  Virion       235
# 236       3      2  Virion       236
# 237       4      3  Virion       237
# 238       -      5  Virion       238
# Wrys
#         Name Might Range                                             Effect  \
# 247  Assault    10     2                                                  -
# 248     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#     SP Cost Default Unlock  Hero  IndexCol
# 247      50       -      1  Wrys       247
# 248     150       -      3  Wrys       248
# Xander
#             Name Might Range  \
# 21    Iron Sword     6     1
# 22   Steel Sword     8     1
# 23  Silver Sword    11     1
# 24     Siegfried    16     1
#
#                                                Effect SP Cost Default Unlock  \
# 21                                                  -      50       -      -
# 22                                                  -     100       3      -
# 23                                                  -     200       4      3
# 24  Enables counterattack regardless of distance i...     400       -      5
#
#       Hero  IndexCol
# 21  Xander        21
# 22  Xander        22
# 23  Xander        23
# 24  Xander        24
# Xander_(Spring_Festival)
#               Name Might Range  \
# 429     Iron Lance     6     1
# 430    Steel Lance     8     1
# 431   Carrot Lance     9     1
# 432  Carrot Lance+    13     1
#
#                                                 Effect SP Cost Default Unlock  \
# 429                                                  -      50       -      -
# 430                                                  -     100       -      -
# 431  If unit initiates attack, unit recovers 4 HP a...     200       -      -
# 432  If unit initiates attack, unit recovers 4 HP a...     300       5      -
#
#                          Hero  IndexCol
# 429  Xander_(Spring_Festival)       429
# 430  Xander_(Spring_Festival)       430
# 431  Xander_(Spring_Festival)       431
# 432  Xander_(Spring_Festival)       432
# Zephiel
#              Name Might Range  \
# 105    Iron Sword     6     1
# 106   Steel Sword     8     1
# 107  Silver Sword    11     1
# 108     Eckesachs    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 105                                                  -      50       -      -
# 106                                                  -     100       3      -
# 107                                                  -     200       4      3
# 108  Inflicts Def-4 on foes within 2 spaces through...     400       -      5
#
#         Hero  IndexCol
# 105  Zephiel       105
# 106  Zephiel       106
# 107  Zephiel       107
# 108  Zephiel       108

# %%
Five = {'red': 20, 'blue': 15, 'green': 9, 'colorless': 14}
Four = {'red': 26, 'blue': 21, 'green': 15, 'colorless': 23}
Three = {'red': 15, 'blue': 12, 'green': 9, 'colorless': 13}

total = 0
red_tot = 0
blue_tot = 0
green_tot = 0 
colorless_tot = 0 

red_five = 0
blue_five = 0
green_five = 0
colorless_five = 0 

red_four = 0 
blue_four = 0 
green_four = 0
colorless_four = 0 

red_three = 0 
blue_three = 0 
green_three = 0 
colorless_three = 0


for key, item in Five.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
    red_five = red_five + item
  elif key == 'blue':
    blue_tot = blue_tot + item
    blue_five = blue_five + item
  elif key == 'green':
    green_tot = green_tot + item
    green_five = green_five + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    colorless_five = colorless_five + item
    
for key, item in Four.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
    red_four = red_four + item
  elif key == 'blue':
    blue_tot = blue_tot + item
    blue_four = blue_four + item
  elif key == 'green':
    green_tot = green_tot + item
    green_four = green_four + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    colorless_four = colorless_four + item 
    
for key, item in Three.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
    red_three = red_three + item 
  elif key == 'blue':
    blue_tot = blue_tot + item
    blue_three = blue_three + item 
  elif key == 'green':
    green_tot = green_tot + item
    green_three = green_three + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    colorless_three = colorless_three + item 
    
five_total = red_five+blue_five+green_five+colorless_five
four_total = red_four+blue_four+green_four+colorless_four
three_total = red_three+blue_three+green_three+colorless_three

focus = {'red': 1, 'blue': 0, 'green': 2, 'colorless': 1}

for key, item in focus.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
  elif key == 'blue':
    blue_tot = blue_tot + item
  elif key == 'green':
    green_tot = green_tot + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    
focus_rsp = .03 * (focus['red']/4)
five_rsp = .03 * (Five['red']/five_total)
four_rsp = .36 * (Four['red']/four_total)
three_rsp = .58 * (Three['red']/three_total)

focus_bsp = .03 * (focus['blue']/4)
five_bsp = .03 * (Five['blue']/five_total)
four_bsp = .36 * (Four['blue']/four_total)
three_bsp = .58 * (Three['blue']/three_total)

focus_gsp = .03 * (focus['green']/4)
five_gsp = .03 * (Five['green']/five_total)
four_gsp = .36 * (Four['green']/four_total)
three_gsp = .58 * (Three['green']/three_total)

focus_csp = .03 * (focus['colorless']/4)
five_csp = .03 * (Five['colorless']/five_total)
four_csp = .36 * (Four['colorless']/four_total)
three_csp = .58 * (Three['colorless']/three_total)

red_percents = ['red', focus_rsp, five_rsp, four_rsp, three_rsp]
blue_percents = ['blue', focus_bsp, five_bsp, four_bsp, three_bsp]
green_percents = ['green', focus_gsp, five_gsp, four_gsp, three_gsp]
colorless_percents = ['colorless', focus_csp, five_csp, four_csp, three_csp]
all_percents = [red_percents, blue_percents, green_percents, colorless_percents]

focus_star_percents = []
five_star_percents = []
four_star_percents = []
three_star_percents = []

for index, i in enumerate(all_percents):
  print(i)
  #print(focus[i[0]])
  print('')
  #print(i[0])
  for ind, j in enumerate(i):
    #print(j)
    #print(ind)
    if ind == 1:
      if focus[i[0]] > 0:
        print('Hero number: ', focus[i[0]], 'Individual percent: ', round((j/focus[i[0]]) * 100, 4))
        focus_star_percents.append(round((j/focus[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')
        focus_star_percents.append(0)
    elif ind == 2:
      if Five[i[0]] > 0:
        print('Hero number: ', Five[i[0]], 'Individual percent: ',round((j/Five[i[0]]) * 100, 4))
        five_star_percents.append(round((j/Five[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')
        five_star_percents.append(0)
    elif ind == 3:
      if Four[i[0]] > 0:
        print('Hero number: ', Four[i[0]], 'Individual percent: ',round((j/Four[i[0]]) * 100, 4))
        four_star_percents.append(round((j/Four[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')
        four_star_percents.append(0)
    elif ind == 4:
      if Three[i[0]] > 0:
        print('Hero number: ', Three[i[0]], 'Individual percent: ',round((j/Three[i[0]]) * 100, 4))
        three_star_percents.append(round((j/Three[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')
        three_star_percents.append(0)

  print('')

print(focus_star_percents)
print(five_star_percents, five_total)
print(four_star_percents, four_total)
print(three_star_percents, three_total)
# Out:
# ['red', 0.0075, 0.010344827586206896, 0.11011764705882353, 0.17755102040816326]
#
# Hero number:  1 Individual percent:  0.75
# Hero number:  20 Individual percent:  0.0517
# Hero number:  26 Individual percent:  0.4235
# Hero number:  15 Individual percent:  1.1837
#
# ['blue', 0.0, 0.007758620689655172, 0.08894117647058823, 0.1420408163265306]
#
# No heroes in category.
# Hero number:  15 Individual percent:  0.0517
# Hero number:  21 Individual percent:  0.4235
# Hero number:  12 Individual percent:  1.1837
#
# ['green', 0.015, 0.004655172413793103, 0.06352941176470589, 0.10653061224489796]
#
# Hero number:  2 Individual percent:  0.75
# Hero number:  9 Individual percent:  0.0517
# Hero number:  15 Individual percent:  0.4235
# Hero number:  9 Individual percent:  1.1837
#
# ['colorless', 0.0075, 0.007241379310344828, 0.09741176470588234, 0.15387755102040815]
#
# Hero number:  1 Individual percent:  0.75
# Hero number:  14 Individual percent:  0.0517
# Hero number:  23 Individual percent:  0.4235
# Hero number:  13 Individual percent:  1.1837
#
# [0.75, 0, 0.75, 0.75]
# [0.0517, 0.0517, 0.0517, 0.0517] 58
# [0.4235, 0.4235, 0.4235, 0.4235] 85
# [1.1837, 1.1837, 1.1837, 1.1837] 49

# %%
#the simple solution, which I will do first, is take the individual percent, which is the percent of appearance rates, divide
#them by the total heroes in each star level or focus, and give each character's corresponding ablities a column in a dataframe
#the percent of them being picked and what skills to include ex:
#Abel is available at 3 stars, so all moves that can be unlocked up to level 3 get 1.1837 percent of being pulled. Then Abel is
#available at 4 stars, so all the moves up to level 4 unlocked get an additional .4235 percent added on. Lower level skills will
#have 1.6072 percent for being pulled and higher level ones will have .4235 percent
#then groupby on 'Name' and sum the pull chance column and all abilites will display the likelihood of being picked!
#
#
#the more complicated solution involves accounting for the orbs availabe in a summoning session. If red orbs are more likely to
#show up, then all red individual values should be more likely to occur, instead of the percents being the same across the board

# %%
replaced_weapons_df = weapons_df['Unlock'].replace('-', 0)
print(weapons_df['Unlock'])
print(replaced_weapons_df)
# Out:
# 417    -
# 418    -
# 419    -
# 420    5
# 89     -
# 90     2
# 91     3
# 92     5
# 153    -
# 154    -
# 155    -
# 156    -
# 253    -
# 254    2
# 255    3
# 256    5
# 33     -
# 34     -
# 35     3
# 36     5
# 328    3
# 329    3
# 343    -
# 344    -
# 345    -
# 346    -
# 57     -
# 58     -
# 59     3
# 60     5
#       ..
# 309    -
# 310    -
# 311    -
# 395    -
# 396    -
# 397    -
# 398    -
# 197    -
# 198    -
# 199    3
# 200    5
# 4      -
# 235    -
# 236    2
# 237    3
# 238    5
# 247    1
# 248    3
# 21     -
# 22     -
# 23     3
# 24     5
# 429    -
# 430    -
# 431    -
# 432    -
# 105    -
# 106    -
# 107    3
# 108    5
# Name: Unlock, dtype: object
# 417    0
# 418    0
# 419    0
# 420    5
# 89     0
# 90     2
# 91     3
# 92     5
# 153    0
# 154    0
# 155    0
# 156    0
# 253    0
# 254    2
# 255    3
# 256    5
# 33     0
# 34     0
# 35     3
# 36     5
# 328    3
# 329    3
# 343    0
# 344    0
# 345    0
# 346    0
# 57     0
# 58     0
# 59     3
# 60     5
#       ..
# 309    0
# 310    0
# 311    0
# 395    0
# 396    0
# 397    0
# 398    0
# 197    0
# 198    0
# 199    3
# 200    5
# 4      0
# 235    0
# 236    2
# 237    3
# 238    5
# 247    1
# 248    3
# 21     0
# 22     0
# 23     3
# 24     5
# 429    0
# 430    0
# 431    0
# 432    0
# 105    0
# 106    0
# 107    3
# 108    5
# Name: Unlock, dtype: object

# %%
print(specials_df.columns)
print(assits_df.columns)
print(passives_df.columns)
# Out:
# Index(['Name', 'Cooldown', 'Effect', 'SP Cost', 'Default', 'Unlock', 'Hero',
#        'IndexCol'],
#       dtype='object')
# Index(['Name', 'Range', 'Effect', 'SP Cost', 'Default', 'Unlock', 'Hero',
#        'IndexCol'],
#       dtype='object')
# Index(['Name', 'Effect', 'SP Cost', 'Unlock', 'Type', 'Hero', 'IndexCol'], dtype='object')

# %%
wep_df = weapons_df.copy()
wep_df['Unlock'] = wep_df['Unlock'].replace('-', 0)

ass_df = assits_df.copy()
ass_df['Unlock'] = ass_df['Unlock'].replace('-', 0)

spe_df = specials_df.copy()
spe_df['Unlock'] = spe_df['Unlock'].replace('-', 0)

pas_df = passives_df.copy()
pas_df['Unlock'] = pas_df['Unlock'].replace('-', 0)

print(wep_df.head())
print(ass_df.head())
print(spe_df.head())
print(pas_df.head())
# Out:
#              Name Might Range                                       Effect  \
# 417    Iron Lance     6     1                                            -
# 418   Steel Lance     8     1                                            -
# 419   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 420  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
# 89     Iron Sword     6     1                                            -
#
#     SP Cost Default Unlock     Hero  IndexCol
# 417      50       -      0     Abel       417
# 418     100       -      0     Abel       418
# 419     200       4      0     Abel       419
# 420     300       5      5     Abel       420
# 89       50       2      0  Alfonse        89
#          Name Range                                             Effect  \
# 3        Swap     1                 Swap places with an adjacent ally.
# 53       Heal     1                                     Restores 5 HP.
# 54  Reconcile     1        Restores 7 HP each to target and this unit.
# 55     Martyr     1  Restores HP=7+ this unit's suffered damage.Uni...
# 57       Sing     1  Enables target to take another action.Cannot b...
#
#    SP Cost Default Unlock    Hero  IndexCol
# 3      150       4      3  Arthur         3
# 53       -       3      0   Azama        53
# 54     100       3      0   Azama        54
# 55     200       -      4   Azama        55
# 57     150       5      0   Azura        57
#                Name Cooldown  \
# 142  Holy Vestments        3
# 143           Aegis        3
# 23         Daylight        4
# 24              Sol        4
# 48      Dragon Gaze        4
#
#                                                 Effect SP Cost Default Unlock  \
# 142  Reduces damage inflicted by attacks from foes ...     100       4      0
# 143  Reduces damage inflicted by attacks from foes ...     200       -      4
# 23                           Heal 30% of damage dealt.     100       2      0
# 24                           Heal 50% of damage dealt.     200       -      4
# 48                                 Grants +30% to Atk.     100       5      0
#
#         Hero  IndexCol
# 142     Abel       142
# 143     Abel       143
# 23   Alfonse        23
# 24   Alfonse        24
# 48       Alm        48
#                Name                                             Effect  \
# 595           HP +3                               Grants +3 to max HP.
# 596           HP +4                               Grants +4 to max HP.
# 597           HP +5                               Grants +5 to max HP.
# 598  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...
# 599  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...
#
#     SP Cost Unlock Type  Hero  IndexCol
# 595      40      0    A  Abel       595
# 596      80      4    A  Abel       596
# 597     160      5    A  Abel       597
# 598      50      0    B  Abel       598
# 599     100      0    B  Abel       599

# %%
all_dfs = [wep_df, ass_df, spe_df, pas_df]
for df in all_dfs:
    for element in df['Unlock']:
        print(type(element))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
